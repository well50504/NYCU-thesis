# %% [markdown]
# ##### import libraries

# %%
import pickle
import numpy as np
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import LeaveOneOut, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import mne

# %% [markdown]
# ##### load features

# %%
def load_pickle_data(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

coh_base_dir = '../../data/COH/'  
pli_base_dir = '../../data/PLI/' 
ste_base_dir = '../../data/STE/'

BD_coh = load_pickle_data(coh_base_dir + 'BD_coh_data.pkl')
BD_pli = load_pickle_data(pli_base_dir + 'BD_pli_data.pkl')
HC_coh = load_pickle_data(coh_base_dir + 'HC_coh_data.pkl')
HC_pli = load_pickle_data(pli_base_dir + 'HC_pli_data.pkl')
BD_ste  = load_pickle_data(ste_base_dir + 'BD_ste_data.pkl')
HC_ste = load_pickle_data(ste_base_dir + 'HC_ste_data.pkl')

# %%
def combine_features(subject_id, coh_dict, pli_dict):

    frequency_bands = ['delta', 'theta', 'alpha', 'betalow', 'betahigh', 'gamma']
    features = []
    for band in frequency_bands:
        features.append(coh_dict[subject_id][band])
    for band in frequency_bands:
        features.append(pli_dict[subject_id][band])
    return np.concatenate(features)

# %%
def combine_features_all(subject_id, coh_dict, pli_dict, ste_dict):

    frequency_bands = ['delta', 'theta', 'alpha', 'betalow', 'betahigh', 'gamma']
    features = []

    for band in frequency_bands:
        features.append(coh_dict[subject_id][band])

    for band in frequency_bands:
        features.append(pli_dict[subject_id][band])

    for band in frequency_bands:
        matrix = ste_dict[subject_id][band]  # shape: (29, 29)
        mask = np.ones(matrix.shape, dtype=bool)
        np.fill_diagonal(mask, False)
        vector = matrix[mask]                #  29*29 - 29 = 812
        features.append(vector)

    return np.concatenate(features)

# %%
BD_subjects = sorted(BD_coh.keys())
HC_subjects = sorted(HC_coh.keys())

n_train_BD = 45
n_train_HC = 45

BD_train_ids = BD_subjects[:n_train_BD]
BD_test_ids  = BD_subjects[n_train_BD:]
HC_train_ids = HC_subjects[:n_train_HC]
HC_test_ids  = HC_subjects[n_train_HC:]

# %%
X_train_list = []
y_train_list = []
train_ids = []

for subj in BD_train_ids:
    feat_vector = combine_features_all(subj, BD_coh, BD_pli, BD_ste)
    X_train_list.append(feat_vector)
    y_train_list.append(0)   # BD label as 0
    train_ids.append(subj)
    
for subj in HC_train_ids:
    feat_vector = combine_features_all(subj, HC_coh, HC_pli, HC_ste)
    X_train_list.append(feat_vector)
    y_train_list.append(1)   # HC label as 1
    train_ids.append(subj)

X_train = np.array(X_train_list)   # shape: (90, 4872)
y_train = np.array(y_train_list)

print("training set data shape:", X_train.shape, y_train.shape)
# Out:
# training set data shape: (90, 9744) (90,)

# %%
X_test_list = []
y_test_list = []
test_ids = []

for subj in BD_test_ids:
    feat_vector = combine_features_all(subj, BD_coh, BD_pli, BD_ste)
    X_test_list.append(feat_vector)
    y_test_list.append(0)
    test_ids.append(subj)
    
for subj in HC_test_ids:
    feat_vector = combine_features_all(subj, HC_coh, HC_pli, HC_ste)
    X_test_list.append(feat_vector)
    y_test_list.append(1)
    test_ids.append(subj)

X_test = np.array(X_test_list)     # shape: (39, 4872)
y_test = np.array(y_test_list)

print("independent test set data shape:", X_test.shape, y_test.shape)
# Out:
# independent test set data shape: (45, 9744) (45,)

# %% [markdown]
# ##### Fisher score

# %%
def compute_fisher_scores(X, y, eps=1e-12):
    N = len(y)  
    n_class0 = np.sum(y == 0)
    n_class1 = np.sum(y == 1)
    p0 = n_class0 / N
    p1 = n_class1 / N
    
    m_global = np.mean(X, axis=0)   # (n_features,)
    
    X_class0 = X[y == 0]
    X_class1 = X[y == 1]
    m0 = np.mean(X_class0, axis=0)
    m1 = np.mean(X_class1, axis=0)
    
    var0 = np.var(X_class0, axis=0)
    var1 = np.var(X_class1, axis=0)
    
    
    S_B = p0 * (m0 - m_global)**2 + p1 * (m1 - m_global)**2
    S_W = p0 * var0 + p1 * var1
    
    Fscore = S_B / (S_W + eps)
    return Fscore


fscores = compute_fisher_scores(X_train, y_train)
top_100_idx = np.argsort(fscores)[-100:]
top_100_idx = top_100_idx[np.argsort(fscores[top_100_idx])[::-1]]

X_train_reduced = X_train[:, top_100_idx]
X_test_reduced  = X_test[:,  top_100_idx]

print("training set data shape:", X_train_reduced.shape)
print("independent test set data shape:",  X_test_reduced.shape)
# print("Top 100 feature indices：", top_100_idx)
# Out:
# training set data shape: (90, 100)
# independent test set data shape: (45, 100)

# %% [markdown]
# ##### SFS + LOPO CV + Grid Search

# %%
def SFS_select(X, y, max_steps, verbose=True):
    cv_obj = LeaveOneOut()

    def evaluate_subset(feature_indices):
        X_sub = X[:, feature_indices]
        lda = LDA()  
        scores = cross_val_score(lda, X_sub, y, cv=cv_obj, n_jobs=-1)
        return scores.mean()

    candidate_features = list(range(X.shape[1]))
    selected = []
    history = []

    best_overall = {
        'subset': None,
        'cv_score': -1,
        'step': None
    }


    for step in range(1, max_steps + 1):
        if verbose:
            print(f"\n[SFS] Step {step}: current subset = {selected}")
        best_feature = None
        best_score = -1

        for f in candidate_features:
            if f in selected:
                continue
            candidate_subset = selected + [f]
            score = evaluate_subset(candidate_subset)
            if verbose:
                print(f"Tested subset {candidate_subset} -> CV Accuracy = {score:.4f}")
            if score > best_score:
                best_score = score
                best_feature = f


        selected.append(best_feature)
        step_record = {
            'step': step,
            'subset': selected.copy(),
            'cv_score': best_score
        }
        history.append(step_record)
        if verbose:
            print(f"--> Step {step} Selected feature {best_feature}, subset = {selected}, CV Accuracy = {best_score:.4f}")


        if best_score > best_overall['cv_score']:
            best_overall['subset'] = selected.copy()
            best_overall['cv_score'] = best_score
            best_overall['step'] = step

    return best_overall, history

# %%
max_steps = 100

print("\n[Start] SFS (Using LOOCV & default LDA) ...")
best_overall, sfs_history = SFS_select(X_train_reduced, y_train, max_steps=max_steps, verbose=True)

print("\n[SFS] Overall optimal result：")
print(f"Optimal subset (size {best_overall['step']}) = {best_overall['subset']}")
print(f"CV accuracy = {best_overall['cv_score']:.4f}")
# Out:
# [Start] SFS (Using LOOCV & default LDA) ...
#
# [SFS] Step 1: current subset = []
# Tested subset [0] -> CV Accuracy = 0.7111
# Tested subset [1] -> CV Accuracy = 0.7111
# Tested subset [2] -> CV Accuracy = 0.7111
# Tested subset [3] -> CV Accuracy = 0.7111
# Tested subset [4] -> CV Accuracy = 0.7333
# Tested subset [5] -> CV Accuracy = 0.7111
# Tested subset [6] -> CV Accuracy = 0.7333
# Tested subset [7] -> CV Accuracy = 0.7111
# Tested subset [8] -> CV Accuracy = 0.6667
# Tested subset [9] -> CV Accuracy = 0.7000
# Tested subset [10] -> CV Accuracy = 0.7000
# Tested subset [11] -> CV Accuracy = 0.6889
# Tested subset [12] -> CV Accuracy = 0.7111
# Tested subset [13] -> CV Accuracy = 0.6778
# Tested subset [14] -> CV Accuracy = 0.7000
# Tested subset [15] -> CV Accuracy = 0.6667
# Tested subset [16] -> CV Accuracy = 0.7000
# Tested subset [17] -> CV Accuracy = 0.7000
# Tested subset [18] -> CV Accuracy = 0.7111
# Tested subset [19] -> CV Accuracy = 0.7000
# Tested subset [20] -> CV Accuracy = 0.7111
# Tested subset [21] -> CV Accuracy = 0.6667
# Tested subset [22] -> CV Accuracy = 0.6889
# Tested subset [23] -> CV Accuracy = 0.7111
# Tested subset [24] -> CV Accuracy = 0.7000
# Tested subset [25] -> CV Accuracy = 0.6556
# Tested subset [26] -> CV Accuracy = 0.6222
# Tested subset [27] -> CV Accuracy = 0.6778
# Tested subset [28] -> CV Accuracy = 0.6889
# Tested subset [29] -> CV Accuracy = 0.6889
# Tested subset [30] -> CV Accuracy = 0.6556
# Tested subset [31] -> CV Accuracy = 0.6556
# Tested subset [32] -> CV Accuracy = 0.6778
# Tested subset [33] -> CV Accuracy = 0.7111
# Tested subset [34] -> CV Accuracy = 0.6889
# Tested subset [35] -> CV Accuracy = 0.7444
# Tested subset [36] -> CV Accuracy = 0.6444
# Tested subset [37] -> CV Accuracy = 0.6778
# Tested subset [38] -> CV Accuracy = 0.6778
# Tested subset [39] -> CV Accuracy = 0.7000
# Tested subset [40] -> CV Accuracy = 0.6667
# Tested subset [41] -> CV Accuracy = 0.6667
# Tested subset [42] -> CV Accuracy = 0.7222
# Tested subset [43] -> CV Accuracy = 0.6444
# Tested subset [44] -> CV Accuracy = 0.6778
# Tested subset [45] -> CV Accuracy = 0.6778
# Tested subset [46] -> CV Accuracy = 0.7333
# Tested subset [47] -> CV Accuracy = 0.6778
# Tested subset [48] -> CV Accuracy = 0.7111
# Tested subset [49] -> CV Accuracy = 0.6556
# Tested subset [50] -> CV Accuracy = 0.6778
# Tested subset [51] -> CV Accuracy = 0.6111
# Tested subset [52] -> CV Accuracy = 0.6889
# Tested subset [53] -> CV Accuracy = 0.6889
# Tested subset [54] -> CV Accuracy = 0.6889
# Tested subset [55] -> CV Accuracy = 0.6667
# Tested subset [56] -> CV Accuracy = 0.6667
# Tested subset [57] -> CV Accuracy = 0.6556
# Tested subset [58] -> CV Accuracy = 0.6444
# Tested subset [59] -> CV Accuracy = 0.6222
# Tested subset [60] -> CV Accuracy = 0.6556
# Tested subset [61] -> CV Accuracy = 0.6556
# Tested subset [62] -> CV Accuracy = 0.6667
# Tested subset [63] -> CV Accuracy = 0.7222
# Tested subset [64] -> CV Accuracy = 0.6556
# Tested subset [65] -> CV Accuracy = 0.6556
# Tested subset [66] -> CV Accuracy = 0.6667
# Tested subset [67] -> CV Accuracy = 0.6778
# Tested subset [68] -> CV Accuracy = 0.6444
# Tested subset [69] -> CV Accuracy = 0.6444
# Tested subset [70] -> CV Accuracy = 0.6444
# Tested subset [71] -> CV Accuracy = 0.6222
# Tested subset [72] -> CV Accuracy = 0.6556
# Tested subset [73] -> CV Accuracy = 0.6556
# Tested subset [74] -> CV Accuracy = 0.6111
# Tested subset [75] -> CV Accuracy = 0.6667
# Tested subset [76] -> CV Accuracy = 0.6333
# Tested subset [77] -> CV Accuracy = 0.6556
# Tested subset [78] -> CV Accuracy = 0.7000
# Tested subset [79] -> CV Accuracy = 0.5889
# Tested subset [80] -> CV Accuracy = 0.6444
# Tested subset [81] -> CV Accuracy = 0.6889
# Tested subset [82] -> CV Accuracy = 0.6444
# Tested subset [83] -> CV Accuracy = 0.6889
# Tested subset [84] -> CV Accuracy = 0.6111
# Tested subset [85] -> CV Accuracy = 0.7111
# Tested subset [86] -> CV Accuracy = 0.6667
# Tested subset [87] -> CV Accuracy = 0.7000
# Tested subset [88] -> CV Accuracy = 0.6444
# Tested subset [89] -> CV Accuracy = 0.6556
# Tested subset [90] -> CV Accuracy = 0.6333
# Tested subset [91] -> CV Accuracy = 0.6333
# Tested subset [92] -> CV Accuracy = 0.6111
# Tested subset [93] -> CV Accuracy = 0.6667
# Tested subset [94] -> CV Accuracy = 0.6556
# Tested subset [95] -> CV Accuracy = 0.6333
# Tested subset [96] -> CV Accuracy = 0.6667
# Tested subset [97] -> CV Accuracy = 0.6889
# Tested subset [98] -> CV Accuracy = 0.7333
# Tested subset [99] -> CV Accuracy = 0.6333
# --> Step 1 Selected feature 35, subset = [35], CV Accuracy = 0.7444
#
# [SFS] Step 2: current subset = [35]
# Tested subset [35, 0] -> CV Accuracy = 0.7778
# Tested subset [35, 1] -> CV Accuracy = 0.7889
# Tested subset [35, 2] -> CV Accuracy = 0.7667
# Tested subset [35, 3] -> CV Accuracy = 0.7667
# Tested subset [35, 4] -> CV Accuracy = 0.7556
# Tested subset [35, 5] -> CV Accuracy = 0.7667
# Tested subset [35, 6] -> CV Accuracy = 0.7556
# Tested subset [35, 7] -> CV Accuracy = 0.7556
# Tested subset [35, 8] -> CV Accuracy = 0.7333
# Tested subset [35, 9] -> CV Accuracy = 0.7667
# Tested subset [35, 10] -> CV Accuracy = 0.7333
# Tested subset [35, 11] -> CV Accuracy = 0.7778
# Tested subset [35, 12] -> CV Accuracy = 0.7556
# Tested subset [35, 13] -> CV Accuracy = 0.7778
# Tested subset [35, 14] -> CV Accuracy = 0.7111
# Tested subset [35, 15] -> CV Accuracy = 0.7222
# Tested subset [35, 16] -> CV Accuracy = 0.7556
# Tested subset [35, 17] -> CV Accuracy = 0.7667
# Tested subset [35, 18] -> CV Accuracy = 0.7444
# Tested subset [35, 19] -> CV Accuracy = 0.7667
# Tested subset [35, 20] -> CV Accuracy = 0.7778
# Tested subset [35, 21] -> CV Accuracy = 0.7889
# Tested subset [35, 22] -> CV Accuracy = 0.8000
# Tested subset [35, 23] -> CV Accuracy = 0.7556
# Tested subset [35, 24] -> CV Accuracy = 0.7222
# Tested subset [35, 25] -> CV Accuracy = 0.7444
# Tested subset [35, 26] -> CV Accuracy = 0.7222
# Tested subset [35, 27] -> CV Accuracy = 0.7778
# Tested subset [35, 28] -> CV Accuracy = 0.7111
# Tested subset [35, 29] -> CV Accuracy = 0.7222
# Tested subset [35, 30] -> CV Accuracy = 0.7444
# Tested subset [35, 31] -> CV Accuracy = 0.7222
# Tested subset [35, 32] -> CV Accuracy = 0.7333
# Tested subset [35, 33] -> CV Accuracy = 0.7333
# Tested subset [35, 34] -> CV Accuracy = 0.7333
# Tested subset [35, 36] -> CV Accuracy = 0.7333
# Tested subset [35, 37] -> CV Accuracy = 0.7667
# Tested subset [35, 38] -> CV Accuracy = 0.7444
# Tested subset [35, 39] -> CV Accuracy = 0.7444
# Tested subset [35, 40] -> CV Accuracy = 0.7778
# Tested subset [35, 41] -> CV Accuracy = 0.8111
# Tested subset [35, 42] -> CV Accuracy = 0.7333
# Tested subset [35, 43] -> CV Accuracy = 0.6889
# Tested subset [35, 44] -> CV Accuracy = 0.7444
# Tested subset [35, 45] -> CV Accuracy = 0.7333
# Tested subset [35, 46] -> CV Accuracy = 0.6889
# Tested subset [35, 47] -> CV Accuracy = 0.7667
# Tested subset [35, 48] -> CV Accuracy = 0.7333
# Tested subset [35, 49] -> CV Accuracy = 0.7444
# Tested subset [35, 50] -> CV Accuracy = 0.7222
# Tested subset [35, 51] -> CV Accuracy = 0.7667
# Tested subset [35, 52] -> CV Accuracy = 0.7000
# Tested subset [35, 53] -> CV Accuracy = 0.7889
# Tested subset [35, 54] -> CV Accuracy = 0.6778
# Tested subset [35, 55] -> CV Accuracy = 0.7667
# Tested subset [35, 56] -> CV Accuracy = 0.7111
# Tested subset [35, 57] -> CV Accuracy = 0.7111
# Tested subset [35, 58] -> CV Accuracy = 0.7111
# Tested subset [35, 59] -> CV Accuracy = 0.7111
# Tested subset [35, 60] -> CV Accuracy = 0.7222
# Tested subset [35, 61] -> CV Accuracy = 0.7222
# Tested subset [35, 62] -> CV Accuracy = 0.7222
# Tested subset [35, 63] -> CV Accuracy = 0.7222
# Tested subset [35, 64] -> CV Accuracy = 0.6667
# Tested subset [35, 65] -> CV Accuracy = 0.7111
# Tested subset [35, 66] -> CV Accuracy = 0.7667
# Tested subset [35, 67] -> CV Accuracy = 0.7778
# Tested subset [35, 68] -> CV Accuracy = 0.7000
# Tested subset [35, 69] -> CV Accuracy = 0.7556
# Tested subset [35, 70] -> CV Accuracy = 0.7333
# Tested subset [35, 71] -> CV Accuracy = 0.7000
# Tested subset [35, 72] -> CV Accuracy = 0.7667
# Tested subset [35, 73] -> CV Accuracy = 0.7000
# Tested subset [35, 74] -> CV Accuracy = 0.7444
# Tested subset [35, 75] -> CV Accuracy = 0.7556
# Tested subset [35, 76] -> CV Accuracy = 0.7222
# Tested subset [35, 77] -> CV Accuracy = 0.7778
# Tested subset [35, 78] -> CV Accuracy = 0.7000
# Tested subset [35, 79] -> CV Accuracy = 0.7778
# Tested subset [35, 80] -> CV Accuracy = 0.7333
# Tested subset [35, 81] -> CV Accuracy = 0.7333
# Tested subset [35, 82] -> CV Accuracy = 0.7667
# Tested subset [35, 83] -> CV Accuracy = 0.7333
# Tested subset [35, 84] -> CV Accuracy = 0.7556
# Tested subset [35, 85] -> CV Accuracy = 0.7333
# Tested subset [35, 86] -> CV Accuracy = 0.7222
# Tested subset [35, 87] -> CV Accuracy = 0.7556
# Tested subset [35, 88] -> CV Accuracy = 0.7333
# Tested subset [35, 89] -> CV Accuracy = 0.7444
# Tested subset [35, 90] -> CV Accuracy = 0.7111
# Tested subset [35, 91] -> CV Accuracy = 0.7444
# Tested subset [35, 92] -> CV Accuracy = 0.7222
# Tested subset [35, 93] -> CV Accuracy = 0.7222
# Tested subset [35, 94] -> CV Accuracy = 0.6889
# Tested subset [35, 95] -> CV Accuracy = 0.7000
# Tested subset [35, 96] -> CV Accuracy = 0.7333
# Tested subset [35, 97] -> CV Accuracy = 0.7889
# Tested subset [35, 98] -> CV Accuracy = 0.7556
# Tested subset [35, 99] -> CV Accuracy = 0.7111
# --> Step 2 Selected feature 41, subset = [35, 41], CV Accuracy = 0.8111
#
# [SFS] Step 3: current subset = [35, 41]
# Tested subset [35, 41, 0] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 1] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 2] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 3] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 4] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 5] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 6] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 7] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 8] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 9] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 10] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 11] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 12] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 13] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 14] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 15] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 16] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 17] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 18] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 19] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 20] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 21] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 22] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 23] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 24] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 25] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 26] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 27] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 28] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 29] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 30] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 31] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 32] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 33] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 34] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 36] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 37] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 38] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 39] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 40] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 42] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 43] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 44] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 45] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 46] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 47] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 48] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 49] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 50] -> CV Accuracy = 0.7444
# Tested subset [35, 41, 51] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 52] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 53] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 54] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 55] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 56] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 57] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 58] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 59] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 60] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 61] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 62] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 63] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 64] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 65] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 66] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 67] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 68] -> CV Accuracy = 0.7444
# Tested subset [35, 41, 69] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 70] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 71] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 72] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 73] -> CV Accuracy = 0.7222
# Tested subset [35, 41, 74] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 75] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 76] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 77] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 78] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 79] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 80] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 81] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 82] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 83] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 85] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 86] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 87] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 88] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 89] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 90] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 91] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 92] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 93] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 94] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 95] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 96] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 97] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 98] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 99] -> CV Accuracy = 0.7556
# --> Step 3 Selected feature 84, subset = [35, 41, 84], CV Accuracy = 0.8333
#
# [SFS] Step 4: current subset = [35, 41, 84]
# Tested subset [35, 41, 84, 0] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 1] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 2] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 3] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 4] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 5] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 6] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 8] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 9] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 10] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 11] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 12] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 13] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 14] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 15] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 16] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 17] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 18] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 19] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 20] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 21] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 22] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 23] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 24] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 25] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 26] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 27] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 28] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 29] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 30] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 31] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 32] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 84, 33] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 34] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 36] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 37] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 38] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 39] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 40] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 42] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 43] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 44] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 45] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 46] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 47] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 48] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 49] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 50] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 51] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 52] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 53] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 54] -> CV Accuracy = 0.7444
# Tested subset [35, 41, 84, 55] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 56] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 57] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 58] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 59] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 60] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 61] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 62] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 63] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 64] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 65] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 66] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 67] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 68] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 69] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 70] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 71] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 72] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 73] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 74] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 75] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 76] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 77] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 78] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 79] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 80] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 81] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 82] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 83] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 85] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 86] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 84, 87] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 88] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 89] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 90] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 91] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 92] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 93] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 94] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 95] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 96] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 97] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 98] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 99] -> CV Accuracy = 0.7778
# --> Step 4 Selected feature 7, subset = [35, 41, 84, 7], CV Accuracy = 0.8556
#
# [SFS] Step 5: current subset = [35, 41, 84, 7]
# Tested subset [35, 41, 84, 7, 0] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 2] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 3] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 4] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 5] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 6] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 8] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 9] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 10] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 11] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 12] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 13] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 14] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 15] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 16] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 17] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 18] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 19] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 20] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 21] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 22] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 23] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 24] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 25] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 26] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 27] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 28] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 29] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 30] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 31] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 32] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 84, 7, 33] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 34] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 36] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 37] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 38] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 39] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 40] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 42] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 43] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 44] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 45] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 46] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 47] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 48] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 49] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 50] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 51] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 52] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 53] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 54] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 55] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 56] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 57] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 58] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 59] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 60] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 61] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 62] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 63] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 64] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 65] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 66] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 67] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 68] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 69] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 70] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 71] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 72] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 73] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 74] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 75] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 76] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 77] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 78] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 79] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 80] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 81] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 82] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 83] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 85] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 86] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 87] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 88] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 89] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 90] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 91] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 92] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 93] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 94] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 95] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 96] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 97] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 98] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 99] -> CV Accuracy = 0.8444
# --> Step 5 Selected feature 1, subset = [35, 41, 84, 7, 1], CV Accuracy = 0.8667
#
# [SFS] Step 6: current subset = [35, 41, 84, 7, 1]
# Tested subset [35, 41, 84, 7, 1, 0] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 2] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 3] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 4] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 5] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 6] -> CV Accuracy = 0.7667
# Tested subset [35, 41, 84, 7, 1, 8] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 9] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 10] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 11] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 12] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 13] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 14] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 15] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 16] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 17] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 18] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 19] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 20] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 21] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 22] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 23] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 25] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 26] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 27] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 28] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 29] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 30] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 31] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 32] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 33] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 34] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 36] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 37] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 38] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 39] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 40] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 42] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 43] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 44] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 45] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 46] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 47] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 48] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 49] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 50] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 51] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 52] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 53] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 54] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 55] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 56] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 57] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 58] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 59] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 60] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 61] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 62] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 63] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 64] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 65] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 66] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 67] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 68] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 69] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 70] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 71] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 72] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 73] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 74] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 75] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 76] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 77] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 78] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 79] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 80] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 81] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 82] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 83] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 85] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 86] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 87] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 88] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 89] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 90] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 91] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 92] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 93] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 94] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 95] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 96] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 97] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 98] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 99] -> CV Accuracy = 0.8444
# --> Step 6 Selected feature 24, subset = [35, 41, 84, 7, 1, 24], CV Accuracy = 0.8667
#
# [SFS] Step 7: current subset = [35, 41, 84, 7, 1, 24]
# Tested subset [35, 41, 84, 7, 1, 24, 0] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 2] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 3] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 4] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 5] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 6] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 8] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 9] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 10] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 11] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 12] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 13] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 14] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 15] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 16] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 17] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 18] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 19] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 84, 7, 1, 24, 20] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 21] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 22] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 23] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 25] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 26] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 27] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 28] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 29] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 30] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 31] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 32] -> CV Accuracy = 0.7444
# Tested subset [35, 41, 84, 7, 1, 24, 33] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 34] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 36] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 37] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 38] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 39] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 40] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 42] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 43] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 44] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 45] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 46] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 47] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 48] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 49] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 50] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 51] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 52] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 53] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 54] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 55] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 56] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 57] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 58] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 59] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 60] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 61] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 62] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 63] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 64] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 65] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 66] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 67] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 24, 68] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 69] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 70] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 71] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 72] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 73] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 74] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 75] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 76] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 77] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 78] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 79] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 80] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 81] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 82] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 83] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 85] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 86] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 87] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 88] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 89] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 90] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 91] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 92] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93] -> CV Accuracy = 0.8667
# Tested subset [35, 41, 84, 7, 1, 24, 94] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 95] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 96] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 97] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 98] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 99] -> CV Accuracy = 0.8333
# --> Step 7 Selected feature 93, subset = [35, 41, 84, 7, 1, 24, 93], CV Accuracy = 0.8667
#
# [SFS] Step 8: current subset = [35, 41, 84, 7, 1, 24, 93]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 0] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 2] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 3] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 4] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 5] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 6] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 8] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 9] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 10] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 11] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 12] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 13] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 14] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 15] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 16] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 17] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 18] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 19] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 21] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 22] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 23] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 25] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 26] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 27] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 28] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 29] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 30] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 31] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 32] -> CV Accuracy = 0.7444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 33] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 34] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 36] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 37] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 38] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 39] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 40] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 42] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 43] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 44] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 45] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 46] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 47] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 48] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 49] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 24, 93, 50] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 51] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 52] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 53] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 54] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 55] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 56] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 57] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 58] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 59] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 60] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 61] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 62] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 63] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 64] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 65] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 66] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 67] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 24, 93, 68] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 69] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 70] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 71] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 72] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 73] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 74] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 75] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 76] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 77] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 78] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 79] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 80] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 81] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 82] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 83] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 85] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 86] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 87] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 88] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 89] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 90] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 91] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 92] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 94] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 95] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 96] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 97] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 98] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 99] -> CV Accuracy = 0.8333
# --> Step 8 Selected feature 20, subset = [35, 41, 84, 7, 1, 24, 93, 20], CV Accuracy = 0.8556
#
# [SFS] Step 9: current subset = [35, 41, 84, 7, 1, 24, 93, 20]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 0] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 2] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 3] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 4] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 5] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 6] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 8] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 9] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 10] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 11] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 12] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 13] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 14] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 15] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 16] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 17] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 18] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 19] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 21] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 22] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 23] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 25] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 26] -> CV Accuracy = 0.7889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 27] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 28] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 29] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 30] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 31] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 32] -> CV Accuracy = 0.7778
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 33] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 34] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 36] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 37] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 38] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 39] -> CV Accuracy = 0.8556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 40] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 42] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 43] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 44] -> CV Accuracy = 0.8111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 45] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 46] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 47] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 48] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 49] -> CV Accuracy = 0.8333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 50] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 51] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 52] -> CV Accuracy = 0.8000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 53] -> CV Accuracy = 0.8222
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 54] -> CV Accuracy = 0.7556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 55] -> CV Accuracy = 0.8444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 56] -> CV Accuracy = 0.8444
# ...
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 87] -> CV Accuracy = 0.6000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 89] -> CV Accuracy = 0.5889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 97] -> CV Accuracy = 0.5556
# --> Step 94 Selected feature 57, subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57], CV Accuracy = 0.6000
#
# [SFS] Step 95: current subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 2] -> CV Accuracy = 0.6333
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 15] -> CV Accuracy = 0.6111
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73] -> CV Accuracy = 0.6556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 87] -> CV Accuracy = 0.5889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 89] -> CV Accuracy = 0.6556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 97] -> CV Accuracy = 0.5556
# --> Step 95 Selected feature 73, subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73], CV Accuracy = 0.6556
#
# [SFS] Step 96: current subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2] -> CV Accuracy = 0.6889
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 15] -> CV Accuracy = 0.6556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 87] -> CV Accuracy = 0.6667
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 89] -> CV Accuracy = 0.6667
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 97] -> CV Accuracy = 0.6333
# --> Step 96 Selected feature 2, subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2], CV Accuracy = 0.6889
#
# [SFS] Step 97: current subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 15] -> CV Accuracy = 0.6444
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 87] -> CV Accuracy = 0.6667
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89] -> CV Accuracy = 0.7000
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 97] -> CV Accuracy = 0.6667
# --> Step 97 Selected feature 89, subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89], CV Accuracy = 0.7000
#
# [SFS] Step 98: current subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 15] -> CV Accuracy = 0.6556
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87] -> CV Accuracy = 0.6667
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 97] -> CV Accuracy = 0.6667
# --> Step 98 Selected feature 87, subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87], CV Accuracy = 0.6667
#
# [SFS] Step 99: current subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87, 15] -> CV Accuracy = 0.6667
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87, 97] -> CV Accuracy = 0.6222
# --> Step 99 Selected feature 15, subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87, 15], CV Accuracy = 0.6667
#
# [SFS] Step 100: current subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87, 15]
# Tested subset [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87, 15, 97] -> CV Accuracy = 0.6222
# --> Step 100 Selected feature 97, subset = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17, 46, 72, 90, 91, 0, 28, 96, 33, 38, 5, 59, 79, 62, 63, 48, 56, 11, 82, 55, 18, 8, 37, 52, 64, 36, 42, 99, 22, 10, 67, 77, 88, 30, 51, 13, 27, 80, 23, 95, 47, 12, 60, 85, 83, 43, 75, 34, 58, 98, 70, 32, 69, 6, 26, 29, 19, 9, 21, 31, 4, 3, 54, 94, 61, 78, 86, 65, 40, 14, 74, 53, 81, 39, 44, 76, 45, 49, 50, 66, 25, 68, 57, 73, 2, 89, 87, 15, 97], CV Accuracy = 0.6222
#
# [SFS] Overall optimal result：
# Optimal subset (size 12) = [35, 41, 84, 7, 1, 24, 93, 20, 71, 16, 92, 17]
# CV accuracy = 0.8778

# %% [markdown]
# ##### ind. test history result

# %%
ind_test_acc_history = []
for record in sfs_history:
    subset = record['subset']
    X_train_cur = X_train_reduced[:, subset]
    X_test_cur = X_test_reduced[:, subset]
    model = LDA()
    model.fit(X_train_cur, y_train)
    y_test_pred = model.predict(X_test_cur)
    test_acc = accuracy_score(y_test, y_test_pred)
    ind_test_acc_history.append(test_acc)


sfs_test_history = []
for rec, acc in zip(sfs_history, ind_test_acc_history):
    new_rec = rec.copy()
    new_rec['ind_test_acc'] = acc
    sfs_test_history.append(new_rec)


with open("result/BD_HC/sfs_test_history.pkl", "wb") as f:
    pickle.dump(sfs_test_history, f)

# %%
with open("result/BD_HC/sfs_test_history.pkl", "rb") as f:
    sfs_test_history = pickle.load(f)

# %% [markdown]
# ##### plot (previous)

# %%
sfs_steps = [record['step'] for record in sfs_history]
sfs_cv_scores = [record['cv_score'] for record in sfs_history]
sfs_ind_test_scores = [record['ind_test_acc'] for record in sfs_test_history]


sns.set_theme(style="whitegrid", context="talk", font_scale=0.8)
plt.figure(figsize=(15, 7))
sns.lineplot(x=sfs_steps, y=sfs_cv_scores, marker="o", markersize=8, lw=2, label="LOPO-CV Accuracy")
sns.lineplot(x=sfs_steps, y=sfs_ind_test_scores, marker="s", markersize=8, lw=2, label="Independent Test Accuracy")
plt.xlabel("Number of Features", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.title("SFS: LOPO-CV vs. Independent Test Accuracy", fontsize=16, fontweight="bold")
plt.legend(fontsize=14)
plt.tight_layout()
# plt.savefig("../result/BD_MDD/sfs_cv_ind_test_accuracy_curve.png", dpi=300)
plt.show()

# %%
sfs_steps = [record['step'] for record in sfs_test_history]
sfs_cv_scores = [record['cv_score'] for record in sfs_test_history]
sfs_ind_test_scores = [record['ind_test_acc'] for record in sfs_test_history]


sfs_cv_scores_pct = [score * 100 for score in sfs_cv_scores]
sfs_ind_test_scores_pct = [score * 100 for score in sfs_ind_test_scores]


sfs_steps_arr = np.array(sfs_steps)
sfs_cv_arr = np.array(sfs_cv_scores_pct)
sfs_ind_test_arr = np.array(sfs_ind_test_scores_pct)


max_cv_index = int(np.argmax(sfs_cv_arr))
max_cv_step = sfs_steps_arr[max_cv_index]
max_cv_accuracy = sfs_cv_arr[max_cv_index]
corresponding_ind_test_at_max_cv = sfs_ind_test_arr[max_cv_index]


max_ind_test_index = int(np.argmax(sfs_ind_test_arr))
max_ind_test_step = sfs_steps_arr[max_ind_test_index]
max_ind_test_accuracy = sfs_ind_test_arr[max_ind_test_index]
corresponding_cv_at_max_ind_test = sfs_cv_arr[max_ind_test_index]

print("\n[Summary of SFS Results]")
print(f"Highest LOOCV Accuracy: {max_cv_accuracy:.1f}% at step {max_cv_step} features")
print(f"    Corresponding Independent Test Accuracy: {corresponding_ind_test_at_max_cv:.1f}%")
print(f"Highest Independent Test Accuracy: {max_ind_test_accuracy:.1f}% at step {max_ind_test_step} features")
print(f"    Corresponding LOOCV Accuracy: {corresponding_cv_at_max_ind_test:.1f}%")


sns.set_theme(style="whitegrid", context="talk", font_scale=0.8)
plt.figure(figsize=(15, 7))

sns.lineplot(x=sfs_steps, y=sfs_cv_scores_pct, marker="o", markersize=8, lw=2, label="LOPO-CV Accuracy")
sns.lineplot(x=sfs_steps, y=sfs_ind_test_scores_pct, marker="s", markersize=8, lw=2, label="Independent Test Accuracy")

plt.xlabel("Number of Features", fontsize=14)
plt.ylabel("Accuracy (%)", fontsize=14)
plt.title("SFS: LOPO-CV vs. Independent Test Accuracy", fontsize=16, fontweight="bold")
plt.legend(fontsize=14)


plt.minorticks_on()
plt.grid(which='both', linestyle='--', linewidth=0.5, alpha=0.7)

plt.tight_layout()
# plt.savefig("../result/BD_MDD/sfs_cv_ind_test_accuracy_curve.png", dpi=300)
plt.show()
# Out:
# [Summary of SFS Results]
# Highest LOOCV Accuracy: 95.6% at step 8 features
#     Corresponding Independent Test Accuracy: 60.0%
# Highest Independent Test Accuracy: 71.1% at step 67 features
#     Corresponding LOOCV Accuracy: 87.8%

# %% [markdown]
# ##### plot

# %%
# extract data from history
sfs_steps       = [record['step'] for record in sfs_test_history]
sfs_cv_scores   = [record['cv_score'] for record in sfs_test_history]
sfs_test_scores = [record['ind_test_acc'] for record in sfs_test_history]
sfs_ind_test_scores = [record['ind_test_acc'] for record in sfs_test_history]

# convert to percentages
cv_pct   = np.array(sfs_cv_scores)  * 100
test_pct = np.array(sfs_test_scores)* 100
steps    = np.array(sfs_steps)

# find LOPO-CV maximum
max_cv_idx     = int(np.argmax(cv_pct))
max_cv_step    = steps[max_cv_idx]
max_cv_value   = cv_pct[max_cv_idx]
test_at_max_cv = test_pct[max_cv_idx]

# find values at 100 features if present
if 100 in steps:
    idx_100     = int(np.where(steps == 100)[0][0])
    cv_at_100   = cv_pct[idx_100]
    test_at_100 = test_pct[idx_100]
else:
    idx_100 = None

# compute means
mean_cv   = cv_pct.mean()
mean_test = test_pct.mean()

# print summary
print(f"Highest LOPO-CV: {max_cv_value:.1f}% at {max_cv_step} features; test = {test_at_max_cv:.1f}%")
if idx_100 is not None:
    print(f"At 100 features: LOPO-CV = {cv_at_100:.1f}%, test = {test_at_100:.1f}%")
else:
    print("No record for 100 features")

# plot
sns.set_theme(style="whitegrid", context="talk", font_scale=0.8)
plt.figure(figsize=(15, 7))

# plot curves with original markers
sns.lineplot(x=steps, y=cv_pct,   marker="o", lw=2, label="LOPO-CV Accuracy")
sns.lineplot(x=steps, y=test_pct, marker="s", lw=2, label="Independent Test Accuracy")

# annotate LOPO-CV max point
plt.text(
    max_cv_step + 1, max_cv_value - 2,
    f"({max_cv_step}, {max_cv_value:.2f}%)",
    fontsize=12
)
plt.text(
    max_cv_step + 1, test_at_max_cv + 1,
    f"({max_cv_step}, {test_at_max_cv:.2f}%)",
    fontsize=12
)

# annotate 100-feature point if exists
if idx_100 is not None:
    plt.text(
        100 + 1, cv_at_100 + 1,
        f"(100, {cv_at_100:.2f}%)",
        fontsize=12
    )
    plt.text(
        100 + 1, test_at_100 - 1,
        f"(100, {test_at_100:.2f}%)",
        fontsize=12
    )


# LOPO-CV max point
plt.scatter(
    max_cv_step, max_cv_value,
    s=200, facecolors='none', edgecolors='red', linewidths=2, marker='o'
)
# corresponding Independent Test at max CV
plt.scatter(
    max_cv_step, test_at_max_cv,
    s=200, facecolors='none', edgecolors='red', linewidths=2, marker='s'
)


# 100-features points
if idx_100 is not None:
    # LOPO-CV at 100
    plt.scatter(
        100, cv_at_100,
        s=200, facecolors='none', edgecolors='red', linewidths=2, marker='o'
    )
    # Independent Test at 100
    plt.scatter(
        100, test_at_100,
        s=200, facecolors='none', edgecolors='red', linewidths=2, marker='s'
    )




# plot mean lines
plt.axhline(mean_cv,   linestyle='--', linewidth=1.5, label=f"Average LOPO-CV: {mean_cv:.2f}%", color='red')
plt.axhline(mean_test, linestyle='--', linewidth=1.5, label=f"Average Test: {mean_test:.2f}%", color='orange')

# labels and legend
plt.xlabel("Number of Features", fontsize=14)
plt.ylabel("Accuracy (%)",        fontsize=14)
plt.title("SFS: LOPO-CV vs Independent Test Accuracy", fontsize=16, fontweight="bold")
plt.minorticks_on()
plt.grid(which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
# plt.savefig("../result/BD_HC/sfs_overall.png", dpi=300)
plt.show()
# Out:
# Highest LOPO-CV: 87.8% at 12 features; test = 57.8%
# At 100 features: LOPO-CV = 62.2%, test = 55.6%

# %% [markdown]
# ##### average result

# %%
# average accuracy of LOOCV
cv_acc_mean = np.mean(sfs_cv_scores) * 100

# highesrt accuracy of LOOCV
cv_acc_max = np.max(sfs_cv_scores) * 100

# average accuracy of independent test set
ind_test_acc_mean = np.mean(sfs_ind_test_scores) * 100

# highest accuracy of independent test set
ind_test_acc_max = np.max(sfs_ind_test_scores) * 100



print("\n[Summary of SFS Results]")
print(f"Average LOOCV Accuracy: {cv_acc_mean:.2f}%")
print(f"Highest LOOCV Accuracy: {cv_acc_max:.2f}%")
print(f"Average Independent Test Accuracy: {ind_test_acc_mean:.2f}%")
print(f"Highest Independent Test Accuracy: {ind_test_acc_max:.2f}%")
# Out:
# [Summary of SFS Results]
# Average LOOCV Accuracy: 90.17%
# Highest LOOCV Accuracy: 95.56%
# Average Independent Test Accuracy: 63.27%
# Highest Independent Test Accuracy: 71.11%

# %% [markdown]
# ##### channel names

# %%
eloc29_path = "../../電極通道/BD_MDD_HC_29_test.loc"
eloc29 = mne.channels.read_custom_montage(eloc29_path)
ch_names = eloc29.ch_names

# %%
def decode_candidate(original_idx, ch_names, frequency_bands=["delta", "theta", "alpha", "betalow", "betahigh", "gamma"]):
    
    len_coh = 406
    len_pli = 406
    len_ste = 812
    coh_end = 6 * len_coh              # 2436
    pli_end = coh_end + 6 * len_pli    # 4872
    ste_end = pli_end + 6 * len_ste    # 9744
    
    if original_idx < coh_end:
        modality = "COH"
        pos = original_idx
        band_idx = pos // len_coh      # 0 ~ 5
        inner_idx = pos % len_coh      # 0 ~ 405
        band = frequency_bands[band_idx]
        r, c = np.triu_indices(len(ch_names), k=1)
        ch1 = ch_names[r[inner_idx]]
        ch2 = ch_names[c[inner_idx]]
        return f"FC Type: {modality}, Band: {band}, Electrodes: {ch1} - {ch2}"
    elif original_idx < pli_end:
        modality = "PLI"
        pos = original_idx - coh_end
        band_idx = pos // len_pli
        inner_idx = pos % len_pli
        band = frequency_bands[band_idx]
        r, c = np.triu_indices(len(ch_names), k=1)
        ch1 = ch_names[r[inner_idx]]
        ch2 = ch_names[c[inner_idx]]
        return f"FC Type: {modality}, Band: {band}, Electrodes: {ch1} - {ch2}"
    elif original_idx < ste_end:
        modality = "STE"
        pos = original_idx - pli_end
        band_idx = pos // len_ste
        inner_idx = pos % len_ste
        band = frequency_bands[band_idx]
        ste_pairs = [(i, j) for i in range(len(ch_names)) for j in range(len(ch_names)) if i != j]
        i, j = ste_pairs[inner_idx]
        return f"FC Type: {modality}, Band: {band}, Direction: {ch_names[i]} -> {ch_names[j]}"
    else:
        return "Index out of range"

def decode_final_feature(candidate_idx, top_100_idx, ch_names, frequency_bands=["delta", "theta", "alpha", "betalow", "betahigh", "gamma"]):
    full_idx = top_100_idx[candidate_idx]
    return decode_candidate(full_idx, ch_names, frequency_bands)

# %%
final_subset_candidate = best_overall["subset"]
print("\n[Result] SFS Optimal feature subset:", final_subset_candidate)


decoded_features = []
modality_counts = {"COH": [], "PLI": [], "STE": []}
for candidate in final_subset_candidate:
    description = decode_final_feature(candidate, top_100_idx, ch_names)
    decoded_features.append(description)

    if "COH" in description:
        modality_counts["COH"].append(description)
    elif "PLI" in description:
        modality_counts["PLI"].append(description)
    elif "STE" in description:
        modality_counts["STE"].append(description)

print("\nDecoded Feature Descriptions:")
for desc in decoded_features:
    print(desc)

print("\nCounts and Details in Final Subset:")
for modality, desc_list in modality_counts.items():
    print(f"{modality}: {len(desc_list)} features")
    for d in desc_list:
        print("  ", d)
# Out:
# [Result] SFS Optimal feature subset: [20, 22, 4, 79, 58, 63, 18, 51]
#
# Decoded Feature Descriptions:
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - F4
# FC Type: PLI, Band: gamma, Electrodes: Cp3 - Fc3
# FC Type: COH, Band: theta, Electrodes: F7 - F8
# FC Type: PLI, Band: betalow, Electrodes: Cpz - P4
# FC Type: PLI, Band: gamma, Electrodes: Fcz - O2
# FC Type: PLI, Band: betahigh, Electrodes: O1 - Cp3
# FC Type: PLI, Band: gamma, Electrodes: F7 - Fcz
# FC Type: PLI, Band: betahigh, Electrodes: Tp8 - T4
#
# Counts and Details in Final Subset:
# COH: 1 features
#    FC Type: COH, Band: theta, Electrodes: F7 - F8
# PLI: 7 features
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - F4
#    FC Type: PLI, Band: gamma, Electrodes: Cp3 - Fc3
#    FC Type: PLI, Band: betalow, Electrodes: Cpz - P4
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - O2
#    FC Type: PLI, Band: betahigh, Electrodes: O1 - Cp3
#    FC Type: PLI, Band: gamma, Electrodes: F7 - Fcz
#    FC Type: PLI, Band: betahigh, Electrodes: Tp8 - T4
# STE: 0 features

# %% [markdown]
# ##### independent test

# %%
with open("result/BD_HC/best_overall.pkl", 'rb') as f:
    best_overall = pickle.load(f)


with open("result/BD_HC/sfs_history.pkl", 'rb') as f:
    sfs_history = pickle.load(f)

# %%
final_subset = best_overall['subset']
print("\n[Result] SFS Optimal feature subset：", final_subset)

X_train_final = X_train_reduced[:, final_subset]
X_test_final  = X_test_reduced[:, final_subset]

final_lda = LDA()
final_lda.fit(X_train_final, y_train)

y_pred_test = final_lda.predict(X_test_final)
test_acc = np.mean(y_pred_test == y_test)
print(f"\n[Ind. Test Result] Accuracy = {test_acc:.6f}")
# Out:
# [Result] SFS Optimal feature subset： [20, 22, 4, 79, 58, 63, 18, 51]
#
# [Ind. Test Result] Accuracy = 0.600000

# %%
sns.reset_defaults()

cm = confusion_matrix(y_test, y_pred_test)
disp_t = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["BD", "MDD"])
disp_t.plot(cmap=plt.cm.Blues)
plt.title("Independent Test Set Confusion Matrix")
plt.tight_layout()
# plt.savefig("../result/BD_MDD/independent_test_confusion_matrix.png")
plt.show()

# %% [markdown]
# ##### save result

# %%
with open("result/BD_HC/best_overall.pkl", "wb") as f:
    pickle.dump(best_overall, f)

with open("result/BD_HC/sfs_history.pkl", "wb") as f:
    pickle.dump(sfs_history, f)

# %% [markdown]
# ##### top 10 features subset

# %%
best_overall_10 = {
    'subset' : sfs_history[99]['subset'],
    'cv_score' : sfs_history[99]['cv_score'],
    'best_params' : sfs_history[99]['best_params'],
    'step' : sfs_history[99]['step']
}

# %%
print("Accuracy:", best_overall_10['cv_score'])
print("Best params:", best_overall_10['best_params'])   
print("Step:", best_overall_10['step'])
print("Subset:", best_overall_10['subset'])
# Out:
# Accuracy: 0.8555555555555555
# Best params: {'C': 100, 'gamma': 0.053535523746494146, 'kernel': 'rbf'}
# Step: 100
# Subset: [20, 22, 4, 79, 58, 63, 18, 51, 0, 10, 13, 21, 15, 44, 57, 80, 88, 5, 64, 1, 8, 92, 11, 26, 78, 36, 46, 29, 49, 40, 43, 52, 7, 6, 55, 65, 37, 14, 98, 93, 82, 85, 16, 28, 86, 56, 45, 53, 3, 19, 48, 27, 59, 61, 12, 62, 9, 95, 84, 33, 72, 24, 71, 74, 23, 67, 30, 2, 32, 17, 42, 99, 47, 66, 69, 25, 35, 81, 89, 94, 54, 60, 73, 39, 34, 31, 38, 83, 87, 90, 70, 75, 76, 77, 97, 68, 41, 96, 50, 91]

# %%
print("ind. test accuracy:", sfs_test_history[9]['ind_test_acc'])
print("ind. test subset:", sfs_test_history[9]['subset'])
print("ind. test params:", sfs_test_history[9]['best_params'])
print("ind. test step:", sfs_test_history[9]['step'])
# Out:
# ind. test accuracy: 0.5777777777777777
# ind. test subset: [20, 22, 4, 79, 58, 63, 18, 51, 0, 10]
# ind. test params: {'C': 100, 'gamma': 4.321942375150668, 'kernel': 'rbf'}
# ind. test step: 10

# %%
final_subset = best_overall_10['subset']
print("\n[Result] SFS Optimal feature subset：", final_subset)

X_train_final = X_train_reduced[:, final_subset]
X_test_final  = X_test_reduced[:, final_subset]


final_lda = LDA()
final_lda.fit(X_train_final, y_train)

y_pred_test = final_lda.predict(X_test_final)
test_acc = np.mean(y_pred_test == y_test)
print(f"\n[Ind. Test Result] Accuracy = {test_acc:.6f}")

sns.reset_defaults()
cm = confusion_matrix(y_test, y_pred_test)
disp_t = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["BD", "MDD"])
disp_t.plot(cmap=plt.cm.Blues)
plt.title("Independent Test Set Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# [Result] SFS Optimal feature subset： [20, 22, 4, 79, 58, 63, 18, 51, 0, 10, 13, 21, 15, 44, 57, 80, 88, 5, 64, 1, 8, 92, 11, 26, 78, 36, 46, 29, 49, 40, 43, 52, 7, 6, 55, 65, 37, 14, 98, 93, 82, 85, 16, 28, 86, 56, 45, 53, 3, 19, 48, 27, 59, 61, 12, 62, 9, 95, 84, 33, 72, 24, 71, 74, 23, 67, 30, 2, 32, 17, 42, 99, 47, 66, 69, 25, 35, 81, 89, 94, 54, 60, 73, 39, 34, 31, 38, 83, 87, 90, 70, 75, 76, 77, 97, 68, 41, 96, 50, 91]
#
# [Ind. Test Result] Accuracy = 0.622222

# %% [markdown]
# ##### top 10 features subset channel name

# %%
# 10 features name
final_subset_10 = best_overall_10['subset']
print("\n[Result] SFS Optimal feature subset：", final_subset_10)
decoded_features_10 = []
modality_counts_10 = {"COH": [], "PLI": [], "STE": []}  
for candidate in final_subset_10:
    description = decode_final_feature(candidate, top_100_idx, ch_names)
    decoded_features_10.append(description)

    if "COH" in description:
        modality_counts_10["COH"].append(description)
    elif "PLI" in description:
        modality_counts_10["PLI"].append(description)
    elif "STE" in description:
        modality_counts_10["STE"].append(description)
print("\nDecoded Feature Descriptions:")
for desc in decoded_features_10:
    print(desc)
print("\nCounts and Details in Final Subset:")
for modality, desc_list in modality_counts_10.items():
    print(f"{modality}: {len(desc_list)} features")
    for d in desc_list:
        print("  ", d)
# Out:
# [Result] SFS Optimal feature subset： [20, 22, 4, 79, 58, 63, 18, 51, 0, 10, 13, 21, 15, 44, 57, 80, 88, 5, 64, 1, 8, 92, 11, 26, 78, 36, 46, 29, 49, 40, 43, 52, 7, 6, 55, 65, 37, 14, 98, 93, 82, 85, 16, 28, 86, 56, 45, 53, 3, 19, 48, 27, 59, 61, 12, 62, 9, 95, 84, 33, 72, 24, 71, 74, 23, 67, 30, 2, 32, 17, 42, 99, 47, 66, 69, 25, 35, 81, 89, 94, 54, 60, 73, 39, 34, 31, 38, 83, 87, 90, 70, 75, 76, 77, 97, 68, 41, 96, 50, 91]
#
# Decoded Feature Descriptions:
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - F4
# FC Type: PLI, Band: gamma, Electrodes: Cp3 - Fc3
# FC Type: COH, Band: theta, Electrodes: F7 - F8
# FC Type: PLI, Band: betalow, Electrodes: Cpz - P4
# FC Type: PLI, Band: gamma, Electrodes: Fcz - O2
# FC Type: PLI, Band: betahigh, Electrodes: O1 - Cp3
# FC Type: PLI, Band: gamma, Electrodes: F7 - Fcz
# FC Type: PLI, Band: betahigh, Electrodes: Tp8 - T4
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - P4
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - C4
# FC Type: STE, Band: alpha, Direction: Fp1 -> F8
# FC Type: STE, Band: theta, Direction: Fp1 -> F8
# FC Type: PLI, Band: gamma, Electrodes: O1 - Fcz
# FC Type: STE, Band: theta, Direction: F7 -> F8
# FC Type: STE, Band: delta, Direction: F8 -> F7
# FC Type: PLI, Band: betahigh, Electrodes: C4 - F8
# FC Type: STE, Band: delta, Direction: Fcz -> O1
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - T6
# FC Type: PLI, Band: betahigh, Electrodes: T3 - Cp3
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - O2
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Oz
# FC Type: PLI, Band: gamma, Electrodes: O1 - Cp3
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Tp8
# FC Type: PLI, Band: betahigh, Electrodes: F7 - Fcz
# FC Type: PLI, Band: betahigh, Electrodes: Ft8 - Tp8
# FC Type: PLI, Band: betalow, Electrodes: Fcz - O2
# FC Type: PLI, Band: betahigh, Electrodes: Cp3 - P4
# FC Type: PLI, Band: betahigh, Electrodes: T3 - Fcz
# FC Type: PLI, Band: gamma, Electrodes: Ft7 - P3
# FC Type: PLI, Band: betalow, Electrodes: Fcz - P4
# FC Type: PLI, Band: betahigh, Electrodes: Cp3 - Fcz
# FC Type: PLI, Band: betahigh, Electrodes: Ft7 - C3
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Cp4
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Fp2
# FC Type: PLI, Band: betalow, Electrodes: Fc3 - Oz
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Tp7
# FC Type: PLI, Band: betalow, Electrodes: Fcz - Oz
# FC Type: PLI, Band: betahigh, Electrodes: O1 - Fcz
# FC Type: PLI, Band: gamma, Electrodes: Fcz - C4
# FC Type: PLI, Band: betahigh, Electrodes: O1 - Fc3
# FC Type: PLI, Band: betalow, Electrodes: Fcz - F4
# FC Type: PLI, Band: gamma, Electrodes: Cpz - Ft8
# FC Type: PLI, Band: gamma, Electrodes: Fcz - Oz
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Cpz
# FC Type: PLI, Band: betalow, Electrodes: Fp1 - Fcz
# FC Type: PLI, Band: gamma, Electrodes: Fcz - T6
# FC Type: PLI, Band: betalow, Electrodes: Fcz - Cp4
# FC Type: PLI, Band: betalow, Electrodes: Fcz - Fp2
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Ft8
# FC Type: PLI, Band: betahigh, Electrodes: Fc3 - Fcz
# FC Type: PLI, Band: gamma, Electrodes: Fcz - P4
# FC Type: PLI, Band: betalow, Electrodes: Fcz - Tp8
# FC Type: PLI, Band: betahigh, Electrodes: T5 - Fcz
# FC Type: PLI, Band: betahigh, Electrodes: T3 - O1
# FC Type: PLI, Band: betalow, Electrodes: Fcz - Ft8
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Ft7
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - F8
# FC Type: PLI, Band: gamma, Electrodes: Cp3 - Fcz
# FC Type: PLI, Band: gamma, Electrodes: P4 - Tp8
# FC Type: PLI, Band: gamma, Electrodes: Fcz - F8
# FC Type: PLI, Band: betalow, Electrodes: Cpz - Tp8
# FC Type: PLI, Band: gamma, Electrodes: Fcz - Tp8
# FC Type: PLI, Band: betalow, Electrodes: Fcz - P3
# FC Type: STE, Band: gamma, Direction: P4 -> Cp4
# FC Type: PLI, Band: betalow, Electrodes: Fcz - T6
# FC Type: PLI, Band: gamma, Electrodes: Fc3 - Fcz
# FC Type: PLI, Band: betalow, Electrodes: Fcz - F8
# FC Type: PLI, Band: betahigh, Electrodes: C4 - Ft7
# FC Type: PLI, Band: betahigh, Electrodes: Fp1 - Fcz
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - T4
# FC Type: PLI, Band: betahigh, Electrodes: T3 - Fc3
# FC Type: PLI, Band: betalow, Electrodes: F7 - Fcz
# FC Type: PLI, Band: betalow, Electrodes: Fcz - T4
# FC Type: PLI, Band: betalow, Electrodes: Cpz - Ft8
# FC Type: PLI, Band: theta, Electrodes: Fcz - O2
# FC Type: COH, Band: theta, Electrodes: Fp1 - F8
# FC Type: PLI, Band: betahigh, Electrodes: Cp3 - Ft8
# FC Type: PLI, Band: gamma, Electrodes: F7 - Fc3
# FC Type: PLI, Band: alpha, Electrodes: Fcz - F4
# FC Type: PLI, Band: gamma, Electrodes: Fcz - T4
# FC Type: PLI, Band: gamma, Electrodes: Fp1 - Fcz
# FC Type: PLI, Band: betalow, Electrodes: O1 - Fcz
# FC Type: COH, Band: delta, Electrodes: F7 - F8
# FC Type: PLI, Band: gamma, Electrodes: Fcz - Fp2
# FC Type: PLI, Band: gamma, Electrodes: Fcz - Ft8
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - P3
# FC Type: PLI, Band: betahigh, Electrodes: Fcz - Pz
# FC Type: PLI, Band: gamma, Electrodes: Fcz - Ft7
# FC Type: PLI, Band: alpha, Electrodes: Fcz - Ft8
# FC Type: PLI, Band: gamma, Electrodes: T3 - Fcz
# FC Type: PLI, Band: betalow, Electrodes: Cpz - Oz
# FC Type: PLI, Band: gamma, Electrodes: P4 - Ft8
# FC Type: COH, Band: alpha, Electrodes: Fp1 - F8
# FC Type: PLI, Band: theta, Electrodes: T3 - Fcz
# FC Type: PLI, Band: alpha, Electrodes: Fcz - T4
# FC Type: COH, Band: theta, Electrodes: F3 - F8
# FC Type: PLI, Band: gamma, Electrodes: T3 - Fc3
# FC Type: PLI, Band: betalow, Electrodes: T3 - Cpz
# FC Type: COH, Band: alpha, Electrodes: F3 - F8
# FC Type: COH, Band: alpha, Electrodes: F7 - F8
#
# Counts and Details in Final Subset:
# COH: 7 features
#    FC Type: COH, Band: theta, Electrodes: F7 - F8
#    FC Type: COH, Band: theta, Electrodes: Fp1 - F8
#    FC Type: COH, Band: delta, Electrodes: F7 - F8
#    FC Type: COH, Band: alpha, Electrodes: Fp1 - F8
#    FC Type: COH, Band: theta, Electrodes: F3 - F8
#    FC Type: COH, Band: alpha, Electrodes: F3 - F8
#    FC Type: COH, Band: alpha, Electrodes: F7 - F8
# PLI: 87 features
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - F4
#    FC Type: PLI, Band: gamma, Electrodes: Cp3 - Fc3
#    FC Type: PLI, Band: betalow, Electrodes: Cpz - P4
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - O2
#    FC Type: PLI, Band: betahigh, Electrodes: O1 - Cp3
#    FC Type: PLI, Band: gamma, Electrodes: F7 - Fcz
#    FC Type: PLI, Band: betahigh, Electrodes: Tp8 - T4
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - P4
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - C4
#    FC Type: PLI, Band: gamma, Electrodes: O1 - Fcz
#    FC Type: PLI, Band: betahigh, Electrodes: C4 - F8
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - T6
#    FC Type: PLI, Band: betahigh, Electrodes: T3 - Cp3
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - O2
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Oz
#    FC Type: PLI, Band: gamma, Electrodes: O1 - Cp3
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Tp8
#    FC Type: PLI, Band: betahigh, Electrodes: F7 - Fcz
#    FC Type: PLI, Band: betahigh, Electrodes: Ft8 - Tp8
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - O2
#    FC Type: PLI, Band: betahigh, Electrodes: Cp3 - P4
#    FC Type: PLI, Band: betahigh, Electrodes: T3 - Fcz
#    FC Type: PLI, Band: gamma, Electrodes: Ft7 - P3
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - P4
#    FC Type: PLI, Band: betahigh, Electrodes: Cp3 - Fcz
#    FC Type: PLI, Band: betahigh, Electrodes: Ft7 - C3
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Cp4
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Fp2
#    FC Type: PLI, Band: betalow, Electrodes: Fc3 - Oz
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Tp7
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - Oz
#    FC Type: PLI, Band: betahigh, Electrodes: O1 - Fcz
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - C4
#    FC Type: PLI, Band: betahigh, Electrodes: O1 - Fc3
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - F4
#    FC Type: PLI, Band: gamma, Electrodes: Cpz - Ft8
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - Oz
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Cpz
#    FC Type: PLI, Band: betalow, Electrodes: Fp1 - Fcz
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - T6
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - Cp4
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - Fp2
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Ft8
#    FC Type: PLI, Band: betahigh, Electrodes: Fc3 - Fcz
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - P4
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - Tp8
#    FC Type: PLI, Band: betahigh, Electrodes: T5 - Fcz
#    FC Type: PLI, Band: betahigh, Electrodes: T3 - O1
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - Ft8
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Ft7
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - F8
#    FC Type: PLI, Band: gamma, Electrodes: Cp3 - Fcz
#    FC Type: PLI, Band: gamma, Electrodes: P4 - Tp8
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - F8
#    FC Type: PLI, Band: betalow, Electrodes: Cpz - Tp8
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - Tp8
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - P3
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - T6
#    FC Type: PLI, Band: gamma, Electrodes: Fc3 - Fcz
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - F8
#    FC Type: PLI, Band: betahigh, Electrodes: C4 - Ft7
#    FC Type: PLI, Band: betahigh, Electrodes: Fp1 - Fcz
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - T4
#    FC Type: PLI, Band: betahigh, Electrodes: T3 - Fc3
#    FC Type: PLI, Band: betalow, Electrodes: F7 - Fcz
#    FC Type: PLI, Band: betalow, Electrodes: Fcz - T4
#    FC Type: PLI, Band: betalow, Electrodes: Cpz - Ft8
#    FC Type: PLI, Band: theta, Electrodes: Fcz - O2
#    FC Type: PLI, Band: betahigh, Electrodes: Cp3 - Ft8
#    FC Type: PLI, Band: gamma, Electrodes: F7 - Fc3
#    FC Type: PLI, Band: alpha, Electrodes: Fcz - F4
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - T4
#    FC Type: PLI, Band: gamma, Electrodes: Fp1 - Fcz
#    FC Type: PLI, Band: betalow, Electrodes: O1 - Fcz
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - Fp2
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - Ft8
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - P3
#    FC Type: PLI, Band: betahigh, Electrodes: Fcz - Pz
#    FC Type: PLI, Band: gamma, Electrodes: Fcz - Ft7
#    FC Type: PLI, Band: alpha, Electrodes: Fcz - Ft8
#    FC Type: PLI, Band: gamma, Electrodes: T3 - Fcz
#    FC Type: PLI, Band: betalow, Electrodes: Cpz - Oz
#    FC Type: PLI, Band: gamma, Electrodes: P4 - Ft8
#    FC Type: PLI, Band: theta, Electrodes: T3 - Fcz
#    FC Type: PLI, Band: alpha, Electrodes: Fcz - T4
#    FC Type: PLI, Band: gamma, Electrodes: T3 - Fc3
#    FC Type: PLI, Band: betalow, Electrodes: T3 - Cpz
# STE: 6 features
#    FC Type: STE, Band: alpha, Direction: Fp1 -> F8
#    FC Type: STE, Band: theta, Direction: Fp1 -> F8
#    FC Type: STE, Band: theta, Direction: F7 -> F8
#    FC Type: STE, Band: delta, Direction: F8 -> F7
#    FC Type: STE, Band: delta, Direction: Fcz -> O1
#    FC Type: STE, Band: gamma, Direction: P4 -> Cp4

# %% [markdown]
# ##### save result

# %%
with open("../result/BD_HC/best_overall_10.pkl", "wb") as f:
    pickle.dump(best_overall_10, f)
