# %% [markdown]
# ##### import libraries

# %%
import pickle
import numpy as np
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import LeaveOneOut, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import mne

# %% [markdown]
# ##### load features

# %%
def load_pickle_data(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

coh_base_dir = '../../data/COH/'  
pli_base_dir = '../../data/PLI/' 
ste_base_dir = '../../data/STE/'

HC_coh = load_pickle_data(coh_base_dir + 'HC_coh_data.pkl')
HC_pli = load_pickle_data(pli_base_dir + 'HC_pli_data.pkl')
MDD_coh = load_pickle_data(coh_base_dir + 'MDD_coh_data.pkl')
MDD_pli = load_pickle_data(pli_base_dir + 'MDD_pli_data.pkl')
HC_ste  = load_pickle_data(ste_base_dir + 'HC_ste_data.pkl')
MDD_ste = load_pickle_data(ste_base_dir + 'MDD_ste_data.pkl')

# %%
def combine_features(subject_id, coh_dict, pli_dict):

    frequency_bands = ['delta', 'theta', 'alpha', 'betalow', 'betahigh', 'gamma']
    features = []
    for band in frequency_bands:
        features.append(coh_dict[subject_id][band])
    for band in frequency_bands:
        features.append(pli_dict[subject_id][band])
    return np.concatenate(features)

# %%
def combine_features_all(subject_id, coh_dict, pli_dict, ste_dict):

    frequency_bands = ['delta', 'theta', 'alpha', 'betalow', 'betahigh', 'gamma']
    features = []

    for band in frequency_bands:
        features.append(coh_dict[subject_id][band])

    for band in frequency_bands:
        features.append(pli_dict[subject_id][band])

    for band in frequency_bands:
        matrix = ste_dict[subject_id][band]  # shape: (29, 29)
        mask = np.ones(matrix.shape, dtype=bool)
        np.fill_diagonal(mask, False)
        vector = matrix[mask]                #  29*29 - 29 = 812
        features.append(vector)

    return np.concatenate(features)

# %%
HC_subjects = sorted(HC_coh.keys())
MDD_subjects = sorted(MDD_coh.keys())

n_train_HC = 45
n_train_MDD = 45

HC_train_ids = HC_subjects[:n_train_HC]
HC_test_ids  = HC_subjects[n_train_HC:]
MDD_train_ids = MDD_subjects[:n_train_MDD]
MDD_test_ids  = MDD_subjects[n_train_MDD:]

# %%
X_train_list = []
y_train_list = []
train_ids = []

for subj in HC_train_ids:
    feat_vector = combine_features_all(subj, HC_coh, HC_pli, HC_ste)
    X_train_list.append(feat_vector)
    y_train_list.append(0)   # HC label as 0
    train_ids.append(subj)
    
for subj in MDD_train_ids:
    feat_vector = combine_features_all(subj, MDD_coh, MDD_pli, MDD_ste)
    X_train_list.append(feat_vector)
    y_train_list.append(1)   # MDD label as 1
    train_ids.append(subj)

X_train = np.array(X_train_list)   # shape: (90, 4872)
y_train = np.array(y_train_list)

print("training set data shape:", X_train.shape, y_train.shape)
# Out:
# training set data shape: (90, 9744) (90,)

# %%
X_test_list = []
y_test_list = []
test_ids = []

for subj in HC_test_ids:
    feat_vector = combine_features_all(subj, HC_coh, HC_pli, HC_ste)
    X_test_list.append(feat_vector)
    y_test_list.append(0)
    test_ids.append(subj)
    
for subj in MDD_test_ids:
    feat_vector = combine_features_all(subj, MDD_coh, MDD_pli, MDD_ste)
    X_test_list.append(feat_vector)
    y_test_list.append(1)
    test_ids.append(subj)

X_test = np.array(X_test_list)     # shape: (39, 4872)
y_test = np.array(y_test_list)

print("independent test set data shape:", X_test.shape, y_test.shape)
# Out:
# independent test set data shape: (46, 9744) (46,)

# %% [markdown]
# ##### Fisher score

# %%
def compute_fisher_scores(X, y, eps=1e-12):
    N = len(y)  
    n_class0 = np.sum(y == 0)
    n_class1 = np.sum(y == 1)
    p0 = n_class0 / N
    p1 = n_class1 / N
    
    m_global = np.mean(X, axis=0)   # (n_features,)
    
    X_class0 = X[y == 0]
    X_class1 = X[y == 1]
    m0 = np.mean(X_class0, axis=0)
    m1 = np.mean(X_class1, axis=0)
    
    var0 = np.var(X_class0, axis=0)
    var1 = np.var(X_class1, axis=0)
    
    
    S_B = p0 * (m0 - m_global)**2 + p1 * (m1 - m_global)**2
    S_W = p0 * var0 + p1 * var1
    
    Fscore = S_B / (S_W + eps)
    return Fscore


fscores = compute_fisher_scores(X_train, y_train)
top_100_idx = np.argsort(fscores)[-100:]
top_100_idx = top_100_idx[np.argsort(fscores[top_100_idx])[::-1]]

X_train_reduced = X_train[:, top_100_idx]
X_test_reduced  = X_test[:,  top_100_idx]

print("training set data shape:", X_train_reduced.shape)
print("independent test set data shape:",  X_test_reduced.shape)
# print("Top 100 feature indices：", top_100_idx)
# Out:
# training set data shape: (90, 100)
# independent test set data shape: (46, 100)

# %% [markdown]
# ##### SFS + LOPO CV + Grid Search

# %%
def SFS_select(X, y, max_steps, verbose=True):
    cv_obj = LeaveOneOut()

    def evaluate_subset(feature_indices):
        X_sub = X[:, feature_indices]
        lda = LDA()  
        scores = cross_val_score(lda, X_sub, y, cv=cv_obj, n_jobs=-1)
        return scores.mean()

    candidate_features = list(range(X.shape[1]))
    selected = []
    history = []

    best_overall = {
        'subset': None,
        'cv_score': -1,
        'step': None
    }


    for step in range(1, max_steps + 1):
        if verbose:
            print(f"\n[SFS] Step {step}: current subset = {selected}")
        best_feature = None
        best_score = -1

        for f in candidate_features:
            if f in selected:
                continue
            candidate_subset = selected + [f]
            score = evaluate_subset(candidate_subset)
            if verbose:
                print(f"Tested subset {candidate_subset} -> CV Accuracy = {score:.4f}")
            if score > best_score:
                best_score = score
                best_feature = f


        selected.append(best_feature)
        step_record = {
            'step': step,
            'subset': selected.copy(),
            'cv_score': best_score
        }
        history.append(step_record)
        if verbose:
            print(f"--> Step {step} Selected feature {best_feature}, subset = {selected}, CV Accuracy = {best_score:.4f}")


        if best_score > best_overall['cv_score']:
            best_overall['subset'] = selected.copy()
            best_overall['cv_score'] = best_score
            best_overall['step'] = step

    return best_overall, history

# %%
max_steps = 100

print("\n[Start] SFS (Using LOOCV & default LDA) ...")
best_overall, sfs_history = SFS_select(X_train_reduced, y_train, max_steps=max_steps, verbose=True)

print("\n[SFS] Overall optimal result：")
print(f"Optimal subset (size {best_overall['step']}) = {best_overall['subset']}")
print(f"CV accuracy = {best_overall['cv_score']:.4f}")
# Out:
# [Start] SFS (Using LOOCV & default LDA) ...
#
# [SFS] Step 1: current subset = []
# Tested subset [0] -> CV Accuracy = 0.6444
# Tested subset [1] -> CV Accuracy = 0.6778
# Tested subset [2] -> CV Accuracy = 0.7000
# Tested subset [3] -> CV Accuracy = 0.6778
# Tested subset [4] -> CV Accuracy = 0.6444
# Tested subset [5] -> CV Accuracy = 0.7000
# Tested subset [6] -> CV Accuracy = 0.7111
# Tested subset [7] -> CV Accuracy = 0.7111
# Tested subset [8] -> CV Accuracy = 0.6333
# Tested subset [9] -> CV Accuracy = 0.6222
# Tested subset [10] -> CV Accuracy = 0.6444
# Tested subset [11] -> CV Accuracy = 0.6556
# Tested subset [12] -> CV Accuracy = 0.7000
# Tested subset [13] -> CV Accuracy = 0.6778
# Tested subset [14] -> CV Accuracy = 0.6778
# Tested subset [15] -> CV Accuracy = 0.6667
# Tested subset [16] -> CV Accuracy = 0.6222
# Tested subset [17] -> CV Accuracy = 0.6444
# Tested subset [18] -> CV Accuracy = 0.6000
# Tested subset [19] -> CV Accuracy = 0.6222
# Tested subset [20] -> CV Accuracy = 0.6222
# Tested subset [21] -> CV Accuracy = 0.6778
# Tested subset [22] -> CV Accuracy = 0.6556
# Tested subset [23] -> CV Accuracy = 0.5889
# Tested subset [24] -> CV Accuracy = 0.6444
# Tested subset [25] -> CV Accuracy = 0.6333
# Tested subset [26] -> CV Accuracy = 0.6556
# Tested subset [27] -> CV Accuracy = 0.6556
# Tested subset [28] -> CV Accuracy = 0.6778
# Tested subset [29] -> CV Accuracy = 0.5667
# Tested subset [30] -> CV Accuracy = 0.6000
# Tested subset [31] -> CV Accuracy = 0.6444
# Tested subset [32] -> CV Accuracy = 0.6444
# Tested subset [33] -> CV Accuracy = 0.6667
# Tested subset [34] -> CV Accuracy = 0.6444
# Tested subset [35] -> CV Accuracy = 0.6444
# Tested subset [36] -> CV Accuracy = 0.6444
# Tested subset [37] -> CV Accuracy = 0.5778
# Tested subset [38] -> CV Accuracy = 0.6556
# Tested subset [39] -> CV Accuracy = 0.6222
# Tested subset [40] -> CV Accuracy = 0.6222
# Tested subset [41] -> CV Accuracy = 0.6556
# Tested subset [42] -> CV Accuracy = 0.6444
# Tested subset [43] -> CV Accuracy = 0.6222
# Tested subset [44] -> CV Accuracy = 0.6444
# Tested subset [45] -> CV Accuracy = 0.6333
# Tested subset [46] -> CV Accuracy = 0.6222
# Tested subset [47] -> CV Accuracy = 0.7111
# Tested subset [48] -> CV Accuracy = 0.5778
# Tested subset [49] -> CV Accuracy = 0.6222
# Tested subset [50] -> CV Accuracy = 0.6000
# Tested subset [51] -> CV Accuracy = 0.6444
# Tested subset [52] -> CV Accuracy = 0.6333
# Tested subset [53] -> CV Accuracy = 0.5889
# Tested subset [54] -> CV Accuracy = 0.6444
# Tested subset [55] -> CV Accuracy = 0.6222
# Tested subset [56] -> CV Accuracy = 0.6222
# Tested subset [57] -> CV Accuracy = 0.5778
# Tested subset [58] -> CV Accuracy = 0.5889
# Tested subset [59] -> CV Accuracy = 0.6222
# Tested subset [60] -> CV Accuracy = 0.6444
# Tested subset [61] -> CV Accuracy = 0.6333
# Tested subset [62] -> CV Accuracy = 0.6111
# Tested subset [63] -> CV Accuracy = 0.6556
# Tested subset [64] -> CV Accuracy = 0.6222
# Tested subset [65] -> CV Accuracy = 0.6778
# Tested subset [66] -> CV Accuracy = 0.6222
# Tested subset [67] -> CV Accuracy = 0.5556
# Tested subset [68] -> CV Accuracy = 0.6444
# Tested subset [69] -> CV Accuracy = 0.6556
# Tested subset [70] -> CV Accuracy = 0.6444
# Tested subset [71] -> CV Accuracy = 0.6111
# Tested subset [72] -> CV Accuracy = 0.6556
# Tested subset [73] -> CV Accuracy = 0.6000
# Tested subset [74] -> CV Accuracy = 0.6778
# Tested subset [75] -> CV Accuracy = 0.6444
# Tested subset [76] -> CV Accuracy = 0.6333
# Tested subset [77] -> CV Accuracy = 0.6444
# Tested subset [78] -> CV Accuracy = 0.6111
# Tested subset [79] -> CV Accuracy = 0.6333
# Tested subset [80] -> CV Accuracy = 0.7000
# Tested subset [81] -> CV Accuracy = 0.6444
# Tested subset [82] -> CV Accuracy = 0.6444
# Tested subset [83] -> CV Accuracy = 0.6000
# Tested subset [84] -> CV Accuracy = 0.6778
# Tested subset [85] -> CV Accuracy = 0.5889
# Tested subset [86] -> CV Accuracy = 0.6111
# Tested subset [87] -> CV Accuracy = 0.6333
# Tested subset [88] -> CV Accuracy = 0.6667
# Tested subset [89] -> CV Accuracy = 0.6333
# Tested subset [90] -> CV Accuracy = 0.6333
# Tested subset [91] -> CV Accuracy = 0.6333
# Tested subset [92] -> CV Accuracy = 0.6000
# Tested subset [93] -> CV Accuracy = 0.6222
# Tested subset [94] -> CV Accuracy = 0.5889
# Tested subset [95] -> CV Accuracy = 0.6222
# Tested subset [96] -> CV Accuracy = 0.5889
# Tested subset [97] -> CV Accuracy = 0.6000
# Tested subset [98] -> CV Accuracy = 0.6333
# Tested subset [99] -> CV Accuracy = 0.6444
# --> Step 1 Selected feature 6, subset = [6], CV Accuracy = 0.7111
#
# [SFS] Step 2: current subset = [6]
# Tested subset [6, 0] -> CV Accuracy = 0.7111
# Tested subset [6, 1] -> CV Accuracy = 0.6889
# Tested subset [6, 2] -> CV Accuracy = 0.7111
# Tested subset [6, 3] -> CV Accuracy = 0.7333
# Tested subset [6, 4] -> CV Accuracy = 0.7000
# Tested subset [6, 5] -> CV Accuracy = 0.7000
# Tested subset [6, 7] -> CV Accuracy = 0.7111
# Tested subset [6, 8] -> CV Accuracy = 0.7000
# Tested subset [6, 9] -> CV Accuracy = 0.7333
# Tested subset [6, 10] -> CV Accuracy = 0.6889
# Tested subset [6, 11] -> CV Accuracy = 0.7667
# Tested subset [6, 12] -> CV Accuracy = 0.7000
# Tested subset [6, 13] -> CV Accuracy = 0.7222
# Tested subset [6, 14] -> CV Accuracy = 0.6889
# Tested subset [6, 15] -> CV Accuracy = 0.6667
# Tested subset [6, 16] -> CV Accuracy = 0.7444
# Tested subset [6, 17] -> CV Accuracy = 0.7222
# Tested subset [6, 18] -> CV Accuracy = 0.6778
# Tested subset [6, 19] -> CV Accuracy = 0.7111
# Tested subset [6, 20] -> CV Accuracy = 0.7222
# Tested subset [6, 21] -> CV Accuracy = 0.7000
# Tested subset [6, 22] -> CV Accuracy = 0.7000
# Tested subset [6, 23] -> CV Accuracy = 0.7333
# Tested subset [6, 24] -> CV Accuracy = 0.7778
# Tested subset [6, 25] -> CV Accuracy = 0.7333
# Tested subset [6, 26] -> CV Accuracy = 0.7333
# Tested subset [6, 27] -> CV Accuracy = 0.7556
# Tested subset [6, 28] -> CV Accuracy = 0.6778
# Tested subset [6, 29] -> CV Accuracy = 0.7556
# Tested subset [6, 30] -> CV Accuracy = 0.7556
# Tested subset [6, 31] -> CV Accuracy = 0.7222
# Tested subset [6, 32] -> CV Accuracy = 0.7333
# Tested subset [6, 33] -> CV Accuracy = 0.7222
# Tested subset [6, 34] -> CV Accuracy = 0.7222
# Tested subset [6, 35] -> CV Accuracy = 0.7111
# Tested subset [6, 36] -> CV Accuracy = 0.6889
# Tested subset [6, 37] -> CV Accuracy = 0.7333
# Tested subset [6, 38] -> CV Accuracy = 0.7000
# Tested subset [6, 39] -> CV Accuracy = 0.6778
# Tested subset [6, 40] -> CV Accuracy = 0.6667
# Tested subset [6, 41] -> CV Accuracy = 0.7333
# Tested subset [6, 42] -> CV Accuracy = 0.7222
# Tested subset [6, 43] -> CV Accuracy = 0.7000
# Tested subset [6, 44] -> CV Accuracy = 0.7111
# Tested subset [6, 45] -> CV Accuracy = 0.7000
# Tested subset [6, 46] -> CV Accuracy = 0.7111
# Tested subset [6, 47] -> CV Accuracy = 0.7556
# Tested subset [6, 48] -> CV Accuracy = 0.7000
# Tested subset [6, 49] -> CV Accuracy = 0.7333
# Tested subset [6, 50] -> CV Accuracy = 0.6889
# Tested subset [6, 51] -> CV Accuracy = 0.6889
# Tested subset [6, 52] -> CV Accuracy = 0.7111
# Tested subset [6, 53] -> CV Accuracy = 0.6778
# Tested subset [6, 54] -> CV Accuracy = 0.6778
# Tested subset [6, 55] -> CV Accuracy = 0.6778
# Tested subset [6, 56] -> CV Accuracy = 0.6889
# Tested subset [6, 57] -> CV Accuracy = 0.6889
# Tested subset [6, 58] -> CV Accuracy = 0.7000
# Tested subset [6, 59] -> CV Accuracy = 0.7000
# Tested subset [6, 60] -> CV Accuracy = 0.7222
# Tested subset [6, 61] -> CV Accuracy = 0.7222
# Tested subset [6, 62] -> CV Accuracy = 0.6778
# Tested subset [6, 63] -> CV Accuracy = 0.7333
# Tested subset [6, 64] -> CV Accuracy = 0.7444
# Tested subset [6, 65] -> CV Accuracy = 0.7000
# Tested subset [6, 66] -> CV Accuracy = 0.7222
# Tested subset [6, 67] -> CV Accuracy = 0.7000
# Tested subset [6, 68] -> CV Accuracy = 0.7222
# Tested subset [6, 69] -> CV Accuracy = 0.7111
# Tested subset [6, 70] -> CV Accuracy = 0.7111
# Tested subset [6, 71] -> CV Accuracy = 0.7111
# Tested subset [6, 72] -> CV Accuracy = 0.6667
# Tested subset [6, 73] -> CV Accuracy = 0.7111
# Tested subset [6, 74] -> CV Accuracy = 0.7333
# Tested subset [6, 75] -> CV Accuracy = 0.7667
# Tested subset [6, 76] -> CV Accuracy = 0.7000
# Tested subset [6, 77] -> CV Accuracy = 0.7000
# Tested subset [6, 78] -> CV Accuracy = 0.7000
# Tested subset [6, 79] -> CV Accuracy = 0.6889
# Tested subset [6, 80] -> CV Accuracy = 0.7222
# Tested subset [6, 81] -> CV Accuracy = 0.7333
# Tested subset [6, 82] -> CV Accuracy = 0.7333
# Tested subset [6, 83] -> CV Accuracy = 0.7111
# Tested subset [6, 84] -> CV Accuracy = 0.7111
# Tested subset [6, 85] -> CV Accuracy = 0.7333
# Tested subset [6, 86] -> CV Accuracy = 0.7444
# Tested subset [6, 87] -> CV Accuracy = 0.6889
# Tested subset [6, 88] -> CV Accuracy = 0.7778
# Tested subset [6, 89] -> CV Accuracy = 0.7444
# Tested subset [6, 90] -> CV Accuracy = 0.7111
# Tested subset [6, 91] -> CV Accuracy = 0.7000
# Tested subset [6, 92] -> CV Accuracy = 0.7556
# Tested subset [6, 93] -> CV Accuracy = 0.6778
# Tested subset [6, 94] -> CV Accuracy = 0.7111
# Tested subset [6, 95] -> CV Accuracy = 0.7333
# Tested subset [6, 96] -> CV Accuracy = 0.6778
# Tested subset [6, 97] -> CV Accuracy = 0.7667
# Tested subset [6, 98] -> CV Accuracy = 0.7333
# Tested subset [6, 99] -> CV Accuracy = 0.7556
# --> Step 2 Selected feature 24, subset = [6, 24], CV Accuracy = 0.7778
#
# [SFS] Step 3: current subset = [6, 24]
# Tested subset [6, 24, 0] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 1] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 2] -> CV Accuracy = 0.7333
# Tested subset [6, 24, 3] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 4] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 5] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 7] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 8] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 9] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 10] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 11] -> CV Accuracy = 0.7333
# Tested subset [6, 24, 12] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 13] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 14] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 15] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 16] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 17] -> CV Accuracy = 0.7333
# Tested subset [6, 24, 18] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 19] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 20] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 21] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 22] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 23] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 25] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 26] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 27] -> CV Accuracy = 0.7222
# Tested subset [6, 24, 28] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 29] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 30] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 31] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 32] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 33] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 34] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 35] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 36] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 37] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 38] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 39] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 40] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 41] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 42] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 43] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 44] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 45] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 46] -> CV Accuracy = 0.7111
# Tested subset [6, 24, 47] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 48] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 49] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 50] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 51] -> CV Accuracy = 0.7222
# Tested subset [6, 24, 52] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 53] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 54] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 55] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 56] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 57] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 58] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 59] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 60] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 61] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 62] -> CV Accuracy = 0.7222
# Tested subset [6, 24, 63] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 64] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 65] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 66] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 67] -> CV Accuracy = 0.7333
# Tested subset [6, 24, 68] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 69] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 70] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 71] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 72] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 73] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 74] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 75] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 76] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 77] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 78] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 79] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 80] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 81] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 82] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 83] -> CV Accuracy = 0.7444
# Tested subset [6, 24, 84] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 85] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 86] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 87] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 88] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 89] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 90] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 91] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 92] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 93] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 94] -> CV Accuracy = 0.7778
# Tested subset [6, 24, 95] -> CV Accuracy = 0.7333
# Tested subset [6, 24, 96] -> CV Accuracy = 0.7667
# Tested subset [6, 24, 97] -> CV Accuracy = 0.7556
# Tested subset [6, 24, 98] -> CV Accuracy = 0.7333
# Tested subset [6, 24, 99] -> CV Accuracy = 0.7556
# --> Step 3 Selected feature 79, subset = [6, 24, 79], CV Accuracy = 0.8333
#
# [SFS] Step 4: current subset = [6, 24, 79]
# Tested subset [6, 24, 79, 0] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 1] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 2] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 3] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 79, 4] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 79, 5] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 7] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 8] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 10] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 11] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 12] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 79, 13] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 14] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 15] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 16] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 17] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 18] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 19] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 79, 20] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 21] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 22] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 23] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 25] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 26] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 27] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 28] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 29] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 30] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 31] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 32] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 33] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 34] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 35] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 79, 36] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 37] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 38] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 39] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 40] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 41] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 42] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 43] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 44] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 45] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 46] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 47] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 48] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 49] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 50] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 51] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 52] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 53] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 54] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 55] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 79, 56] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 57] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 58] -> CV Accuracy = 0.7889
# Tested subset [6, 24, 79, 59] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 60] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 61] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 62] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 63] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 64] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 65] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 66] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 67] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 68] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 69] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 70] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 71] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 72] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 73] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 74] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 75] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 76] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 77] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 78] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 80] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 81] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 82] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 83] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 84] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 85] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 86] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 87] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 88] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 89] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 90] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 91] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 92] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 93] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 94] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 95] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 96] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 97] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 98] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 99] -> CV Accuracy = 0.8000
# --> Step 4 Selected feature 9, subset = [6, 24, 79, 9], CV Accuracy = 0.8778
#
# [SFS] Step 5: current subset = [6, 24, 79, 9]
# Tested subset [6, 24, 79, 9, 0] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 1] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 9, 2] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 3] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 9, 4] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 5] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 7] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 8] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 10] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 9, 11] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 12] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 13] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 14] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 15] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 16] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 17] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 18] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 19] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 20] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 21] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 22] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 23] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 25] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 26] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 27] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 28] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 29] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 30] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 31] -> CV Accuracy = 0.8000
# Tested subset [6, 24, 79, 9, 32] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 33] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 34] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 35] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 36] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 37] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 38] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 39] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 40] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 41] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 42] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 43] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 44] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 45] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 46] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 47] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 48] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 49] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 50] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 51] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 52] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 53] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 54] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 55] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 56] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 57] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 58] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 59] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 9, 60] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 61] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 62] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 9, 63] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 64] -> CV Accuracy = 0.8222
# Tested subset [6, 24, 79, 9, 65] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 66] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 67] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 68] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 69] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 70] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 71] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 72] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 73] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 74] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 75] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 76] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 77] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 78] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 80] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 81] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 82] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 83] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 84] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 85] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 86] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 87] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 88] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 89] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 90] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 91] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 92] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 93] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 94] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 95] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 96] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 97] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 98] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 99] -> CV Accuracy = 0.8444
# --> Step 5 Selected feature 75, subset = [6, 24, 79, 9, 75], CV Accuracy = 0.8778
#
# [SFS] Step 6: current subset = [6, 24, 79, 9, 75]
# Tested subset [6, 24, 79, 9, 75, 0] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 1] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 75, 2] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 3] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 4] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 5] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 7] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 8] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 10] -> CV Accuracy = 0.8111
# Tested subset [6, 24, 79, 9, 75, 11] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 12] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 13] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 14] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 15] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 75, 16] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 17] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 18] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 19] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 21] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 22] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 23] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 25] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 26] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 27] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 28] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 29] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 30] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 31] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 75, 32] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 33] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 34] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 35] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 36] -> CV Accuracy = 0.8333
# Tested subset [6, 24, 79, 9, 75, 37] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 38] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 39] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 40] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 41] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 42] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 43] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 44] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 45] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 46] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 47] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 48] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 75, 49] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 50] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 51] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 52] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 53] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 54] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 55] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 56] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 57] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 58] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 59] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 60] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 61] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 62] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 63] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 64] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 65] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 66] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 67] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 68] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 69] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 70] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 71] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 72] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 73] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 74] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 76] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 77] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 78] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 80] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 81] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 82] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 75, 83] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 84] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 85] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 86] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 87] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 88] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 89] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 90] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 91] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 92] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 93] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 94] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 95] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 96] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 97] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 98] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 99] -> CV Accuracy = 0.8778
# --> Step 6 Selected feature 20, subset = [6, 24, 79, 9, 75, 20], CV Accuracy = 0.9111
#
# [SFS] Step 7: current subset = [6, 24, 79, 9, 75, 20]
# Tested subset [6, 24, 79, 9, 75, 20, 0] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 1] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 2] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 3] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 4] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 5] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 7] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 10] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 20, 11] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 12] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 13] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 14] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 15] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 16] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 17] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 18] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 19] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 21] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 22] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 23] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 25] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 26] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 27] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 28] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 29] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 30] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 31] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 20, 32] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 33] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 34] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 35] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 36] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 37] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 38] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 39] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 40] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 41] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 42] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 43] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 44] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 45] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 46] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 47] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 48] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 49] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 50] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 51] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 52] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 53] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 54] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 55] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 56] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 57] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 58] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 59] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 60] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 61] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 62] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 63] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 64] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 65] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 66] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 67] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 68] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 69] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 70] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 71] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 72] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 73] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 74] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 76] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 77] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 78] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 80] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 81] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 82] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 83] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 84] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 85] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 86] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 87] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 88] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 89] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 90] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 91] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 92] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 93] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 94] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 95] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 96] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 97] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 98] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 99] -> CV Accuracy = 0.9111
# --> Step 7 Selected feature 8, subset = [6, 24, 79, 9, 75, 20, 8], CV Accuracy = 0.9222
#
# [SFS] Step 8: current subset = [6, 24, 79, 9, 75, 20, 8]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 0] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 1] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 20, 8, 2] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 3] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 4] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 5] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 10] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 11] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 12] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 13] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 14] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 15] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 16] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 17] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 18] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 19] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 21] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 22] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 23] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 25] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 26] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 27] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 28] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 29] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 30] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 31] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 32] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 33] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 34] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 35] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 36] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 37] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 38] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 39] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 40] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 41] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 42] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 43] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 44] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 45] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 46] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 47] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 48] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 49] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 50] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 51] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 52] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 53] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 54] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 55] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 56] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 57] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 58] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 59] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 60] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 61] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 62] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 63] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 64] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 65] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 66] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 67] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 68] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 69] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 70] -> CV Accuracy = 0.8444
# Tested subset [6, 24, 79, 9, 75, 20, 8, 71] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 72] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 73] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 74] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 76] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 77] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 78] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 80] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 81] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 82] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 83] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 84] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 85] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 86] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 87] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 88] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 89] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 90] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 91] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 92] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 93] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 94] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 95] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 96] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 97] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 98] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 99] -> CV Accuracy = 0.9000
# --> Step 8 Selected feature 7, subset = [6, 24, 79, 9, 75, 20, 8, 7], CV Accuracy = 0.9222
#
# [SFS] Step 9: current subset = [6, 24, 79, 9, 75, 20, 8, 7]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 0] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 1] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 2] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 3] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 4] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 5] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 10] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 11] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 12] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 13] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 14] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 16] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 17] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 18] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 19] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 21] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 22] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 23] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 25] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 26] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 27] -> CV Accuracy = 0.8556
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 28] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 29] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 30] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 31] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 32] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 33] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 34] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 35] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 36] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 37] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 38] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 39] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 40] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 41] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 42] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 43] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 44] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 45] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 46] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 47] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 48] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 49] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 50] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 51] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 52] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 53] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 54] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 55] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 56] -> CV Accuracy = 0.8889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 57] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 58] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 59] -> CV Accuracy = 0.8667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 60] -> CV Accuracy = 0.9222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 61] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 62] -> CV Accuracy = 0.9000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 63] -> CV Accuracy = 0.8778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 64] -> CV Accuracy = 0.9111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 65] -> CV Accuracy = 0.9111
# ...
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 92] -> CV Accuracy = 0.5556
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 98] -> CV Accuracy = 0.5889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 99] -> CV Accuracy = 0.5556
# --> Step 94 Selected feature 84, subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84], CV Accuracy = 0.6333
#
# [SFS] Step 95: current subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 63] -> CV Accuracy = 0.5778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 86] -> CV Accuracy = 0.5333
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 91] -> CV Accuracy = 0.5444
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 92] -> CV Accuracy = 0.5444
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98] -> CV Accuracy = 0.6111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 99] -> CV Accuracy = 0.5222
# --> Step 95 Selected feature 98, subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98], CV Accuracy = 0.6111
#
# [SFS] Step 96: current subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63] -> CV Accuracy = 0.6111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 86] -> CV Accuracy = 0.5667
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 91] -> CV Accuracy = 0.5556
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 92] -> CV Accuracy = 0.5778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 99] -> CV Accuracy = 0.5556
# --> Step 96 Selected feature 63, subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63], CV Accuracy = 0.6111
#
# [SFS] Step 97: current subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 86] -> CV Accuracy = 0.6111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91] -> CV Accuracy = 0.6222
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 92] -> CV Accuracy = 0.5778
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 99] -> CV Accuracy = 0.5444
# --> Step 97 Selected feature 91, subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91], CV Accuracy = 0.6222
#
# [SFS] Step 98: current subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86] -> CV Accuracy = 0.6111
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 92] -> CV Accuracy = 0.6000
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 99] -> CV Accuracy = 0.5444
# --> Step 98 Selected feature 86, subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86], CV Accuracy = 0.6111
#
# [SFS] Step 99: current subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 92] -> CV Accuracy = 0.5889
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99] -> CV Accuracy = 0.6222
# --> Step 99 Selected feature 99, subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99], CV Accuracy = 0.6222
#
# [SFS] Step 100: current subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99]
# Tested subset [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99, 92] -> CV Accuracy = 0.5889
# --> Step 100 Selected feature 92, subset = [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99, 92], CV Accuracy = 0.5889
#
# [SFS] Overall optimal result：
# Optimal subset (size 7) = [6, 24, 79, 9, 75, 20, 8]
# CV accuracy = 0.9222

# %% [markdown]
# ##### ind. test history result

# %%
ind_test_acc_history = []
for record in sfs_history:
    subset = record['subset']
    X_train_cur = X_train_reduced[:, subset]
    X_test_cur = X_test_reduced[:, subset]
    model = LDA()
    model.fit(X_train_cur, y_train)
    y_test_pred = model.predict(X_test_cur)
    test_acc = accuracy_score(y_test, y_test_pred)
    ind_test_acc_history.append(test_acc)


sfs_test_history = []
for rec, acc in zip(sfs_history, ind_test_acc_history):
    new_rec = rec.copy()
    new_rec['ind_test_acc'] = acc
    sfs_test_history.append(new_rec)


with open("result/MDD_HC/sfs_test_history.pkl", "wb") as f:
    pickle.dump(sfs_test_history, f)

# %%
with open("result/MDD_HC/sfs_test_history.pkl", "rb") as f:
    sfs_test_history = pickle.load(f)

# %% [markdown]
# ##### plot (previous)

# %%
sfs_steps = [record['step'] for record in sfs_history]
sfs_cv_scores = [record['cv_score'] for record in sfs_history]
sfs_ind_test_scores = [record['ind_test_acc'] for record in sfs_test_history]


sns.set_theme(style="whitegrid", context="talk", font_scale=0.8)
plt.figure(figsize=(15, 7))
sns.lineplot(x=sfs_steps, y=sfs_cv_scores, marker="o", markersize=8, lw=2, label="LOPO-CV Accuracy")
sns.lineplot(x=sfs_steps, y=sfs_ind_test_scores, marker="s", markersize=8, lw=2, label="Independent Test Accuracy")
plt.xlabel("Number of Features", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.title("SFS: LOPO-CV vs. Independent Test Accuracy", fontsize=16, fontweight="bold")
plt.legend(fontsize=14)
plt.tight_layout()
# plt.savefig("../result/BD_MDD/sfs_cv_ind_test_accuracy_curve.png", dpi=300)
plt.show()

# %%
sfs_steps = [record['step'] for record in sfs_test_history]
sfs_cv_scores = [record['cv_score'] for record in sfs_test_history]
sfs_ind_test_scores = [record['ind_test_acc'] for record in sfs_test_history]


sfs_cv_scores_pct = [score * 100 for score in sfs_cv_scores]
sfs_ind_test_scores_pct = [score * 100 for score in sfs_ind_test_scores]


sfs_steps_arr = np.array(sfs_steps)
sfs_cv_arr = np.array(sfs_cv_scores_pct)
sfs_ind_test_arr = np.array(sfs_ind_test_scores_pct)


max_cv_index = int(np.argmax(sfs_cv_arr))
max_cv_step = sfs_steps_arr[max_cv_index]
max_cv_accuracy = sfs_cv_arr[max_cv_index]
corresponding_ind_test_at_max_cv = sfs_ind_test_arr[max_cv_index]


max_ind_test_index = int(np.argmax(sfs_ind_test_arr))
max_ind_test_step = sfs_steps_arr[max_ind_test_index]
max_ind_test_accuracy = sfs_ind_test_arr[max_ind_test_index]
corresponding_cv_at_max_ind_test = sfs_cv_arr[max_ind_test_index]

print("\n[Summary of SFS Results]")
print(f"Highest LOOCV Accuracy: {max_cv_accuracy:.1f}% at step {max_cv_step} features")
print(f"    Corresponding Independent Test Accuracy: {corresponding_ind_test_at_max_cv:.1f}%")
print(f"Highest Independent Test Accuracy: {max_ind_test_accuracy:.1f}% at step {max_ind_test_step} features")
print(f"    Corresponding LOOCV Accuracy: {corresponding_cv_at_max_ind_test:.1f}%")


sns.set_theme(style="whitegrid", context="talk", font_scale=0.8)
plt.figure(figsize=(15, 7))

sns.lineplot(x=sfs_steps, y=sfs_cv_scores_pct, marker="o", markersize=8, lw=2, label="LOPO-CV Accuracy")
sns.lineplot(x=sfs_steps, y=sfs_ind_test_scores_pct, marker="s", markersize=8, lw=2, label="Independent Test Accuracy")

plt.xlabel("Number of Features", fontsize=14)
plt.ylabel("Accuracy (%)", fontsize=14)
plt.title("SFS: LOPO-CV vs. Independent Test Accuracy", fontsize=16, fontweight="bold")
plt.legend(fontsize=14)


plt.minorticks_on()
plt.grid(which='both', linestyle='--', linewidth=0.5, alpha=0.7)

plt.tight_layout()
# plt.savefig("../result/BD_MDD/sfs_cv_ind_test_accuracy_curve.png", dpi=300)
plt.show()
# Out:
# [Summary of SFS Results]
# Highest LOOCV Accuracy: 95.6% at step 48 features
#     Corresponding Independent Test Accuracy: 73.9%
# Highest Independent Test Accuracy: 80.4% at step 90 features
#     Corresponding LOOCV Accuracy: 84.4%

# %% [markdown]
# ##### plot

# %%
# extract data from history
sfs_steps       = [record['step'] for record in sfs_test_history]
sfs_cv_scores   = [record['cv_score'] for record in sfs_test_history]
sfs_test_scores = [record['ind_test_acc'] for record in sfs_test_history]
sfs_ind_test_scores = [record['ind_test_acc'] for record in sfs_test_history]

# convert to percentages
cv_pct   = np.array(sfs_cv_scores)  * 100
test_pct = np.array(sfs_test_scores)* 100
steps    = np.array(sfs_steps)

# find LOPO-CV maximum
max_cv_idx     = int(np.argmax(cv_pct))
max_cv_step    = steps[max_cv_idx]
max_cv_value   = cv_pct[max_cv_idx]
test_at_max_cv = test_pct[max_cv_idx]

# find values at 100 features if present
if 100 in steps:
    idx_100     = int(np.where(steps == 100)[0][0])
    cv_at_100   = cv_pct[idx_100]
    test_at_100 = test_pct[idx_100]
else:
    idx_100 = None

# compute means
mean_cv   = cv_pct.mean()
mean_test = test_pct.mean()

# print summary
print(f"Highest LOPO-CV: {max_cv_value:.1f}% at {max_cv_step} features; test = {test_at_max_cv:.1f}%")
if idx_100 is not None:
    print(f"At 100 features: LOPO-CV = {cv_at_100:.1f}%, test = {test_at_100:.1f}%")
else:
    print("No record for 100 features")

# plot
sns.set_theme(style="whitegrid", context="talk", font_scale=0.8)
plt.figure(figsize=(15, 7))

# plot curves with original markers
sns.lineplot(x=steps, y=cv_pct,   marker="o", lw=2, label="LOPO-CV Accuracy")
sns.lineplot(x=steps, y=test_pct, marker="s", lw=2, label="Independent Test Accuracy")

# annotate LOPO-CV max point
plt.text(
    max_cv_step + 1, max_cv_value + 1,
    f"({max_cv_step}, {max_cv_value:.2f}%)",
    fontsize=12
)
plt.text(
    max_cv_step + 1, test_at_max_cv - 2,
    f"({max_cv_step}, {test_at_max_cv:.2f}%)",
    fontsize=12
)

# annotate 100-feature point if exists
if idx_100 is not None:
    plt.text(
        100 + 1, cv_at_100 + 1,
        f"(100, {cv_at_100:.2f}%)",
        fontsize=12
    )
    plt.text(
        100 + 1, test_at_100 - 1,
        f"(100, {test_at_100:.2f}%)",
        fontsize=12
    )


# LOPO-CV max point
plt.scatter(
    max_cv_step, max_cv_value,
    s=200, facecolors='none', edgecolors='red', linewidths=2, marker='o'
)
# corresponding Independent Test at max CV
plt.scatter(
    max_cv_step, test_at_max_cv,
    s=200, facecolors='none', edgecolors='red', linewidths=2, marker='s'
)


# 100-features points
if idx_100 is not None:
    # LOPO-CV at 100
    plt.scatter(
        100, cv_at_100,
        s=200, facecolors='none', edgecolors='red', linewidths=2, marker='o'
    )
    # Independent Test at 100
    plt.scatter(
        100, test_at_100,
        s=200, facecolors='none', edgecolors='red', linewidths=2, marker='s'
    )




# plot mean lines
plt.axhline(mean_cv,   linestyle='--', linewidth=1.5, label=f"Average LOPO-CV: {mean_cv:.2f}%", color='red')
plt.axhline(mean_test, linestyle='--', linewidth=1.5, label=f"Average Test: {mean_test:.2f}%", color='orange')

# labels and legend
plt.xlabel("Number of Features", fontsize=14)
plt.ylabel("Accuracy (%)",        fontsize=14)
plt.title("SFS: LOPO-CV vs Independent Test Accuracy", fontsize=16, fontweight="bold")
plt.minorticks_on()
plt.grid(which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
# plt.savefig("result/MDD_HC/sfs_overall.png", dpi=300)
plt.show()
# Out:
# Highest LOPO-CV: 92.2% at 7 features; test = 71.7%
# At 100 features: LOPO-CV = 58.9%, test = 54.3%

# %% [markdown]
# ##### average result

# %%
# average accuracy of LOOCV
cv_acc_mean = np.mean(sfs_cv_scores) * 100

# highesrt accuracy of LOOCV
cv_acc_max = np.max(sfs_cv_scores) * 100

# average accuracy of independent test set
ind_test_acc_mean = np.mean(sfs_ind_test_scores) * 100

# highest accuracy of independent test set
ind_test_acc_max = np.max(sfs_ind_test_scores) * 100



print("\n[Summary of SFS Results]")
print(f"Average LOOCV Accuracy: {cv_acc_mean:.2f}%")
print(f"Highest LOOCV Accuracy: {cv_acc_max:.2f}%")
print(f"Average Independent Test Accuracy: {ind_test_acc_mean:.2f}%")
print(f"Highest Independent Test Accuracy: {ind_test_acc_max:.2f}%")
# Out:
# [Summary of SFS Results]
# Average LOOCV Accuracy: 78.86%
# Highest LOOCV Accuracy: 92.22%
# Average Independent Test Accuracy: 67.35%
# Highest Independent Test Accuracy: 82.61%

# %% [markdown]
# ##### channel names

# %%
eloc29_path = "../../電極通道/BD_MDD_HC_29_test.loc"
eloc29 = mne.channels.read_custom_montage(eloc29_path)
ch_names = eloc29.ch_names

# %%
def decode_candidate(original_idx, ch_names, frequency_bands=["delta", "theta", "alpha", "betalow", "betahigh", "gamma"]):
    
    len_coh = 406
    len_pli = 406
    len_ste = 812
    coh_end = 6 * len_coh              # 2436
    pli_end = coh_end + 6 * len_pli    # 4872
    ste_end = pli_end + 6 * len_ste    # 9744
    
    if original_idx < coh_end:
        modality = "COH"
        pos = original_idx
        band_idx = pos // len_coh      # 0 ~ 5
        inner_idx = pos % len_coh      # 0 ~ 405
        band = frequency_bands[band_idx]
        r, c = np.triu_indices(len(ch_names), k=1)
        ch1 = ch_names[r[inner_idx]]
        ch2 = ch_names[c[inner_idx]]
        return f"FC Type: {modality}, Band: {band}, Electrodes: {ch1} - {ch2}"
    elif original_idx < pli_end:
        modality = "PLI"
        pos = original_idx - coh_end
        band_idx = pos // len_pli
        inner_idx = pos % len_pli
        band = frequency_bands[band_idx]
        r, c = np.triu_indices(len(ch_names), k=1)
        ch1 = ch_names[r[inner_idx]]
        ch2 = ch_names[c[inner_idx]]
        return f"FC Type: {modality}, Band: {band}, Electrodes: {ch1} - {ch2}"
    elif original_idx < ste_end:
        modality = "STE"
        pos = original_idx - pli_end
        band_idx = pos // len_ste
        inner_idx = pos % len_ste
        band = frequency_bands[band_idx]
        ste_pairs = [(i, j) for i in range(len(ch_names)) for j in range(len(ch_names)) if i != j]
        i, j = ste_pairs[inner_idx]
        return f"FC Type: {modality}, Band: {band}, Direction: {ch_names[i]} -> {ch_names[j]}"
    else:
        return "Index out of range"

def decode_final_feature(candidate_idx, top_100_idx, ch_names, frequency_bands=["delta", "theta", "alpha", "betalow", "betahigh", "gamma"]):
    full_idx = top_100_idx[candidate_idx]
    return decode_candidate(full_idx, ch_names, frequency_bands)

# %%
final_subset_candidate = best_overall["subset"]
print("\n[Result] SFS Optimal feature subset:", final_subset_candidate)


decoded_features = []
modality_counts = {"COH": [], "PLI": [], "STE": []}
for candidate in final_subset_candidate:
    description = decode_final_feature(candidate, top_100_idx, ch_names)
    decoded_features.append(description)

    if "COH" in description:
        modality_counts["COH"].append(description)
    elif "PLI" in description:
        modality_counts["PLI"].append(description)
    elif "STE" in description:
        modality_counts["STE"].append(description)

print("\nDecoded Feature Descriptions:")
for desc in decoded_features:
    print(desc)

print("\nCounts and Details in Final Subset:")
for modality, desc_list in modality_counts.items():
    print(f"{modality}: {len(desc_list)} features")
    for d in desc_list:
        print("  ", d)
# Out:
# [Result] SFS Optimal feature subset: [6, 24, 79, 9, 75, 20, 8]
#
# Decoded Feature Descriptions:
# FC Type: COH, Band: betalow, Electrodes: F3 - Fz
# FC Type: PLI, Band: delta, Electrodes: Cp4 - T4
# FC Type: PLI, Band: alpha, Electrodes: T3 - Ft7
# FC Type: PLI, Band: delta, Electrodes: T5 - T4
# FC Type: PLI, Band: theta, Electrodes: Fp1 - T4
# FC Type: PLI, Band: delta, Electrodes: T5 - Fc3
# FC Type: STE, Band: betalow, Direction: Cp4 -> C4
#
# Counts and Details in Final Subset:
# COH: 1 features
#    FC Type: COH, Band: betalow, Electrodes: F3 - Fz
# PLI: 5 features
#    FC Type: PLI, Band: delta, Electrodes: Cp4 - T4
#    FC Type: PLI, Band: alpha, Electrodes: T3 - Ft7
#    FC Type: PLI, Band: delta, Electrodes: T5 - T4
#    FC Type: PLI, Band: theta, Electrodes: Fp1 - T4
#    FC Type: PLI, Band: delta, Electrodes: T5 - Fc3
# STE: 1 features
#    FC Type: STE, Band: betalow, Direction: Cp4 -> C4

# %% [markdown]
# ##### independent test

# %%
with open("result/MDD_HC/best_overall.pkl", 'rb') as f:
    best_overall = pickle.load(f)


with open("result/MDD_HC/sfs_history.pkl", 'rb') as f:
    sfs_history = pickle.load(f)

# %%
final_subset = best_overall['subset']
print("\n[Result] SFS Optimal feature subset：", final_subset)

X_train_final = X_train_reduced[:, final_subset]
X_test_final  = X_test_reduced[:, final_subset]

final_svm = SVC(**best_overall['best_params'])
final_svm.fit(X_train_final, y_train)

y_pred_test = final_svm.predict(X_test_final)
test_acc = np.mean(y_pred_test == y_test)
print(f"\n[Ind. Test Result] Accuracy = {test_acc:.6f}")
# Out:
# [Result] SFS Optimal feature subset： [6, 75, 3, 7, 2, 11, 9, 26, 90, 1, 13, 17, 28, 30, 42, 55, 62, 4, 34, 74, 38, 43, 68, 88, 18, 15, 25, 50, 54, 71, 40, 73, 93, 97, 19, 32, 46, 87, 48, 8, 84, 22, 5, 20, 21, 10, 12, 56]
#
# [Ind. Test Result] Accuracy = 0.739130

# %%
sns.reset_defaults()

cm = confusion_matrix(y_test, y_pred_test)
disp_t = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["HC", "MDD"])
disp_t.plot(cmap=plt.cm.Blues)
plt.title("Independent Test Set Confusion Matrix")
plt.tight_layout()
# plt.savefig("../result/BD_MDD/independent_test_confusion_matrix.png")
plt.show()

# %% [markdown]
# ##### save result

# %%
with open("result/MDD_HC/best_overall.pkl", "wb") as f:
    pickle.dump(best_overall, f)

with open("result/MDD_HC/sfs_history.pkl", "wb") as f:
    pickle.dump(sfs_history, f)

# %% [markdown]
# ##### top 100 features subset

# %%
best_overall_10 = {
    'subset' : sfs_history[99]['subset'],
    'cv_score' : sfs_history[99]['cv_score'],
    'step' : sfs_history[99]['step']
}

# %%
print("Accuracy:", best_overall_10['cv_score']) 
print("Step:", best_overall_10['step'])
print("Subset:", best_overall_10['subset'])
# Out:
# Accuracy: 0.5888888888888889
# Step: 100
# Subset: [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99, 92]

# %%
print("ind. test accuracy:", sfs_test_history[99]['ind_test_acc'])
print("ind. test subset:", sfs_test_history[99]['subset'])
print("ind. test step:", sfs_test_history[99]['step'])
# Out:
# ind. test accuracy: 0.5434782608695652
# ind. test subset: [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99, 92]
# ind. test step: 100

# %%
final_subset = best_overall_10['subset']
print("\n[Result] SFS Optimal feature subset：", final_subset)

X_train_final = X_train_reduced[:, final_subset]
X_test_final  = X_test_reduced[:, final_subset]


final_lda = LDA()
final_lda.fit(X_train_final, y_train)

y_pred_test = final_lda.predict(X_test_final)
test_acc = np.mean(y_pred_test == y_test)
print(f"\n[Ind. Test Result] Accuracy = {test_acc:.6f}")

sns.reset_defaults()
cm = confusion_matrix(y_test, y_pred_test)
disp_t = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["BD", "MDD"])
disp_t.plot(cmap=plt.cm.Blues)
plt.title("Independent Test Set Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# [Result] SFS Optimal feature subset： [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99, 92]
#
# [Ind. Test Result] Accuracy = 0.543478

# %% [markdown]
# ##### top 10 features subset channel name

# %%
# 10 features name
final_subset_10 = best_overall_10['subset']
print("\n[Result] SFS Optimal feature subset：", final_subset_10)
decoded_features_10 = []
modality_counts_10 = {"COH": [], "PLI": [], "STE": []}  
for candidate in final_subset_10:
    description = decode_final_feature(candidate, top_100_idx, ch_names)
    decoded_features_10.append(description)

    if "COH" in description:
        modality_counts_10["COH"].append(description)
    elif "PLI" in description:
        modality_counts_10["PLI"].append(description)
    elif "STE" in description:
        modality_counts_10["STE"].append(description)
print("\nDecoded Feature Descriptions:")
for desc in decoded_features_10:
    print(desc)
print("\nCounts and Details in Final Subset:")
for modality, desc_list in modality_counts_10.items():
    print(f"{modality}: {len(desc_list)} features")
    for d in desc_list:
        print("  ", d)
# Out:
# [Result] SFS Optimal feature subset： [6, 24, 79, 9, 75, 20, 8, 7, 15, 13, 49, 46, 12, 3, 14, 25, 0, 53, 64, 50, 22, 58, 21, 57, 30, 76, 11, 70, 41, 80, 94, 61, 60, 26, 71, 72, 69, 89, 34, 66, 17, 2, 67, 78, 40, 27, 1, 31, 37, 29, 16, 38, 51, 42, 32, 33, 74, 44, 19, 88, 43, 45, 52, 65, 48, 87, 10, 55, 35, 36, 54, 77, 28, 56, 39, 18, 59, 5, 62, 97, 68, 82, 90, 73, 85, 83, 95, 4, 81, 96, 47, 93, 23, 84, 98, 63, 91, 86, 99, 92]
#
# Decoded Feature Descriptions:
# FC Type: COH, Band: betalow, Electrodes: F3 - Fz
# FC Type: PLI, Band: delta, Electrodes: Cp4 - T4
# FC Type: PLI, Band: alpha, Electrodes: T3 - Ft7
# FC Type: PLI, Band: delta, Electrodes: T5 - T4
# FC Type: PLI, Band: theta, Electrodes: Fp1 - T4
# FC Type: PLI, Band: delta, Electrodes: T5 - Fc3
# FC Type: STE, Band: betalow, Direction: Cp4 -> C4
# FC Type: STE, Band: alpha, Direction: F3 -> Fz
# FC Type: STE, Band: betalow, Direction: Fz -> Fcz
# FC Type: STE, Band: gamma, Direction: Fp2 -> Fz
# FC Type: PLI, Band: delta, Electrodes: Tp7 - C3
# FC Type: PLI, Band: delta, Electrodes: Cpz - Tp8
# FC Type: COH, Band: betalow, Electrodes: Fz - Fp2
# FC Type: STE, Band: betalow, Direction: Fp2 -> Fz
# FC Type: COH, Band: gamma, Electrodes: F3 - Fz
# FC Type: PLI, Band: delta, Electrodes: Fc3 - Tp7
# FC Type: PLI, Band: delta, Electrodes: T3 - Fc3
# FC Type: PLI, Band: delta, Electrodes: P3 - Fc4
# FC Type: PLI, Band: delta, Electrodes: Fc3 - T4
# FC Type: STE, Band: betahigh, Direction: F3 -> Fz
# FC Type: STE, Band: gamma, Direction: P4 -> Cp4
# FC Type: PLI, Band: delta, Electrodes: Oz - O2
# FC Type: COH, Band: alpha, Electrodes: F3 - Fz
# FC Type: PLI, Band: delta, Electrodes: F7 - Cp4
# FC Type: STE, Band: alpha, Direction: Fp2 -> Fz
# FC Type: STE, Band: betalow, Direction: C4 -> Fc4
# FC Type: PLI, Band: delta, Electrodes: T3 - F3
# FC Type: COH, Band: delta, Electrodes: Fp1 - T6
# FC Type: STE, Band: betahigh, Direction: P4 -> Cp4
# FC Type: COH, Band: betalow, Electrodes: Tp8 - O2
# FC Type: PLI, Band: delta, Electrodes: Cpz - T4
# FC Type: COH, Band: delta, Electrodes: Fp1 - T4
# FC Type: COH, Band: gamma, Electrodes: C4 - Fc4
# FC Type: COH, Band: delta, Electrodes: Cp3 - Fp1
# FC Type: PLI, Band: delta, Electrodes: Tp7 - Fc4
# FC Type: STE, Band: betahigh, Direction: Cp4 -> C4
# FC Type: STE, Band: betalow, Direction: Fc4 -> C4
# FC Type: COH, Band: delta, Electrodes: O1 - F8
# FC Type: STE, Band: alpha, Direction: Fz -> Fcz
# FC Type: PLI, Band: betahigh, Electrodes: Ft7 - C3
# FC Type: PLI, Band: delta, Electrodes: T5 - Fc4
# FC Type: STE, Band: betalow, Direction: F3 -> Fz
# FC Type: PLI, Band: delta, Electrodes: Tp8 - T4
# FC Type: PLI, Band: delta, Electrodes: Fc3 - Tp8
# FC Type: STE, Band: betahigh, Direction: O2 -> P4
# FC Type: COH, Band: delta, Electrodes: Fp1 - P3
# FC Type: STE, Band: gamma, Direction: F3 -> Fz
# FC Type: PLI, Band: delta, Electrodes: Tp8 - C3
# FC Type: PLI, Band: delta, Electrodes: Oz - T6
# FC Type: PLI, Band: delta, Electrodes: T3 - F7
# FC Type: PLI, Band: delta, Electrodes: Tp7 - T4
# FC Type: STE, Band: gamma, Direction: F4 -> Fz
# FC Type: PLI, Band: delta, Electrodes: T5 - Tp8
# FC Type: STE, Band: betahigh, Direction: Fp2 -> Fz
# FC Type: STE, Band: betalow, Direction: P4 -> Cp4
# FC Type: PLI, Band: delta, Electrodes: P4 - C3
# FC Type: COH, Band: delta, Electrodes: Cp3 - Fp2
# FC Type: COH, Band: betalow, Electrodes: Fcz - Fz
# FC Type: COH, Band: betahigh, Electrodes: F3 - Fz
# FC Type: PLI, Band: betalow, Electrodes: T3 - C4
# FC Type: STE, Band: betalow, Direction: Fp1 -> Fz
# FC Type: COH, Band: betahigh, Electrodes: Fz - Fp2
# FC Type: STE, Band: betahigh, Direction: Cp4 -> P4
# FC Type: COH, Band: betahigh, Electrodes: Fcz - Fz
# FC Type: STE, Band: betalow, Direction: Cp4 -> P4
# FC Type: STE, Band: alpha, Direction: O2 -> P4
# FC Type: STE, Band: betalow, Direction: F3 -> Fc3
# FC Type: STE, Band: gamma, Direction: Fz -> F4
# FC Type: PLI, Band: delta, Electrodes: T3 - C3
# FC Type: COH, Band: betahigh, Electrodes: P4 - Cp4
# FC Type: STE, Band: betalow, Direction: Fp2 -> F4
# FC Type: COH, Band: betalow, Electrodes: P4 - O2
# FC Type: STE, Band: betalow, Direction: O2 -> P4
# FC Type: COH, Band: betalow, Electrodes: Fp1 - Fz
# FC Type: COH, Band: betalow, Electrodes: P4 - Cp4
# FC Type: PLI, Band: delta, Electrodes: Ft8 - T4
# FC Type: COH, Band: delta, Electrodes: F8 - T6
# FC Type: PLI, Band: delta, Electrodes: C3 - T6
# FC Type: STE, Band: betalow, Direction: O2 -> Oz
# FC Type: PLI, Band: delta, Electrodes: Cp3 - C4
# FC Type: STE, Band: betalow, Direction: Fz -> F3
# FC Type: PLI, Band: theta, Electrodes: P4 - T6
# FC Type: STE, Band: betalow, Direction: Cp3 -> C3
# FC Type: STE, Band: gamma, Direction: Cp4 -> Oz
# FC Type: PLI, Band: delta, Electrodes: F7 - Tp8
# FC Type: PLI, Band: delta, Electrodes: Fcz - C4
# FC Type: COH, Band: delta, Electrodes: Fcz - Tp7
# FC Type: STE, Band: gamma, Direction: Fz -> F3
# FC Type: COH, Band: delta, Electrodes: Fc3 - Fp1
# FC Type: PLI, Band: delta, Electrodes: Fcz - Tp8
# FC Type: COH, Band: delta, Electrodes: P3 - F8
# FC Type: STE, Band: alpha, Direction: Fz -> F3
# FC Type: PLI, Band: delta, Electrodes: C3 - T4
# FC Type: STE, Band: betalow, Direction: Fcz -> Fz
# FC Type: COH, Band: delta, Electrodes: T3 - Fp2
# FC Type: COH, Band: delta, Electrodes: Fp1 - Tp7
# FC Type: COH, Band: betahigh, Electrodes: C4 - Fc4
# FC Type: COH, Band: alpha, Electrodes: Fz - Fp2
# FC Type: COH, Band: delta, Electrodes: O2 - F8
# FC Type: PLI, Band: delta, Electrodes: F7 - T4
#
# Counts and Details in Final Subset:
# COH: 29 features
#    FC Type: COH, Band: betalow, Electrodes: F3 - Fz
#    FC Type: COH, Band: betalow, Electrodes: Fz - Fp2
#    FC Type: COH, Band: gamma, Electrodes: F3 - Fz
#    FC Type: COH, Band: alpha, Electrodes: F3 - Fz
#    FC Type: COH, Band: delta, Electrodes: Fp1 - T6
#    FC Type: COH, Band: betalow, Electrodes: Tp8 - O2
#    FC Type: COH, Band: delta, Electrodes: Fp1 - T4
#    FC Type: COH, Band: gamma, Electrodes: C4 - Fc4
#    FC Type: COH, Band: delta, Electrodes: Cp3 - Fp1
#    FC Type: COH, Band: delta, Electrodes: O1 - F8
#    FC Type: COH, Band: delta, Electrodes: Fp1 - P3
#    FC Type: COH, Band: delta, Electrodes: Cp3 - Fp2
#    FC Type: COH, Band: betalow, Electrodes: Fcz - Fz
#    FC Type: COH, Band: betahigh, Electrodes: F3 - Fz
#    FC Type: COH, Band: betahigh, Electrodes: Fz - Fp2
#    FC Type: COH, Band: betahigh, Electrodes: Fcz - Fz
#    FC Type: COH, Band: betahigh, Electrodes: P4 - Cp4
#    FC Type: COH, Band: betalow, Electrodes: P4 - O2
#    FC Type: COH, Band: betalow, Electrodes: Fp1 - Fz
#    FC Type: COH, Band: betalow, Electrodes: P4 - Cp4
#    FC Type: COH, Band: delta, Electrodes: F8 - T6
#    FC Type: COH, Band: delta, Electrodes: Fcz - Tp7
#    FC Type: COH, Band: delta, Electrodes: Fc3 - Fp1
#    FC Type: COH, Band: delta, Electrodes: P3 - F8
#    FC Type: COH, Band: delta, Electrodes: T3 - Fp2
#    FC Type: COH, Band: delta, Electrodes: Fp1 - Tp7
#    FC Type: COH, Band: betahigh, Electrodes: C4 - Fc4
#    FC Type: COH, Band: alpha, Electrodes: Fz - Fp2
#    FC Type: COH, Band: delta, Electrodes: O2 - F8
# PLI: 37 features
#    FC Type: PLI, Band: delta, Electrodes: Cp4 - T4
#    FC Type: PLI, Band: alpha, Electrodes: T3 - Ft7
#    FC Type: PLI, Band: delta, Electrodes: T5 - T4
#    FC Type: PLI, Band: theta, Electrodes: Fp1 - T4
#    FC Type: PLI, Band: delta, Electrodes: T5 - Fc3
#    FC Type: PLI, Band: delta, Electrodes: Tp7 - C3
#    FC Type: PLI, Band: delta, Electrodes: Cpz - Tp8
#    FC Type: PLI, Band: delta, Electrodes: Fc3 - Tp7
#    FC Type: PLI, Band: delta, Electrodes: T3 - Fc3
#    FC Type: PLI, Band: delta, Electrodes: P3 - Fc4
#    FC Type: PLI, Band: delta, Electrodes: Fc3 - T4
#    FC Type: PLI, Band: delta, Electrodes: Oz - O2
#    FC Type: PLI, Band: delta, Electrodes: F7 - Cp4
#    FC Type: PLI, Band: delta, Electrodes: T3 - F3
#    FC Type: PLI, Band: delta, Electrodes: Cpz - T4
#    FC Type: PLI, Band: delta, Electrodes: Tp7 - Fc4
#    FC Type: PLI, Band: betahigh, Electrodes: Ft7 - C3
#    FC Type: PLI, Band: delta, Electrodes: T5 - Fc4
#    FC Type: PLI, Band: delta, Electrodes: Tp8 - T4
#    FC Type: PLI, Band: delta, Electrodes: Fc3 - Tp8
#    FC Type: PLI, Band: delta, Electrodes: Tp8 - C3
#    FC Type: PLI, Band: delta, Electrodes: Oz - T6
#    FC Type: PLI, Band: delta, Electrodes: T3 - F7
#    FC Type: PLI, Band: delta, Electrodes: Tp7 - T4
#    FC Type: PLI, Band: delta, Electrodes: T5 - Tp8
#    FC Type: PLI, Band: delta, Electrodes: P4 - C3
#    FC Type: PLI, Band: betalow, Electrodes: T3 - C4
#    FC Type: PLI, Band: delta, Electrodes: T3 - C3
#    FC Type: PLI, Band: delta, Electrodes: Ft8 - T4
#    FC Type: PLI, Band: delta, Electrodes: C3 - T6
#    FC Type: PLI, Band: delta, Electrodes: Cp3 - C4
#    FC Type: PLI, Band: theta, Electrodes: P4 - T6
#    FC Type: PLI, Band: delta, Electrodes: F7 - Tp8
#    FC Type: PLI, Band: delta, Electrodes: Fcz - C4
#    FC Type: PLI, Band: delta, Electrodes: Fcz - Tp8
#    FC Type: PLI, Band: delta, Electrodes: C3 - T4
#    FC Type: PLI, Band: delta, Electrodes: F7 - T4
# STE: 34 features
#    FC Type: STE, Band: betalow, Direction: Cp4 -> C4
#    FC Type: STE, Band: alpha, Direction: F3 -> Fz
#    FC Type: STE, Band: betalow, Direction: Fz -> Fcz
#    FC Type: STE, Band: gamma, Direction: Fp2 -> Fz
#    FC Type: STE, Band: betalow, Direction: Fp2 -> Fz
#    FC Type: STE, Band: betahigh, Direction: F3 -> Fz
#    FC Type: STE, Band: gamma, Direction: P4 -> Cp4
#    FC Type: STE, Band: alpha, Direction: Fp2 -> Fz
#    FC Type: STE, Band: betalow, Direction: C4 -> Fc4
#    FC Type: STE, Band: betahigh, Direction: P4 -> Cp4
#    FC Type: STE, Band: betahigh, Direction: Cp4 -> C4
#    FC Type: STE, Band: betalow, Direction: Fc4 -> C4
#    FC Type: STE, Band: alpha, Direction: Fz -> Fcz
#    FC Type: STE, Band: betalow, Direction: F3 -> Fz
#    FC Type: STE, Band: betahigh, Direction: O2 -> P4
#    FC Type: STE, Band: gamma, Direction: F3 -> Fz
#    FC Type: STE, Band: gamma, Direction: F4 -> Fz
#    FC Type: STE, Band: betahigh, Direction: Fp2 -> Fz
#    FC Type: STE, Band: betalow, Direction: P4 -> Cp4
#    FC Type: STE, Band: betalow, Direction: Fp1 -> Fz
#    FC Type: STE, Band: betahigh, Direction: Cp4 -> P4
#    FC Type: STE, Band: betalow, Direction: Cp4 -> P4
#    FC Type: STE, Band: alpha, Direction: O2 -> P4
#    FC Type: STE, Band: betalow, Direction: F3 -> Fc3
#    FC Type: STE, Band: gamma, Direction: Fz -> F4
#    FC Type: STE, Band: betalow, Direction: Fp2 -> F4
#    FC Type: STE, Band: betalow, Direction: O2 -> P4
#    FC Type: STE, Band: betalow, Direction: O2 -> Oz
#    FC Type: STE, Band: betalow, Direction: Fz -> F3
#    FC Type: STE, Band: betalow, Direction: Cp3 -> C3
#    FC Type: STE, Band: gamma, Direction: Cp4 -> Oz
#    FC Type: STE, Band: gamma, Direction: Fz -> F3
#    FC Type: STE, Band: alpha, Direction: Fz -> F3
#    FC Type: STE, Band: betalow, Direction: Fcz -> Fz

# %% [markdown]
# ##### save result

# %%
with open("../result/MDD_HC/best_overall_5.pkl", "wb") as f:
    pickle.dump(best_overall_10, f)
